# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
import pandas as pd
import numpy as np
import re
import string
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K
from nltk.corpus import stopwords  
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
import nltk
nltk.download('stopwords')
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Read the Data
data1 = pd.read_csv('Reviews.csv')
print(data1.columns)
#remove uneccessary columns 
data1 = data1.drop(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
       'HelpfulnessDenominator', 'Score', 'Time'], axis = 1)
print("Removed unecessary columns")
print(data1.head())
for i in range(5):
  print(data1.Text[i])
  print(data1.Summary[i])
  print('\n')
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')
# Removed unecessary columns
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# Good Quality Dog Food
#
#
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# Not as Advertised
#
#
# This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.
# "Delight" says it all
#
#
# If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.
# Cough Medicine
#
#
# Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# Great taffy

# %%
# Read the Data
data2 = pd.read_csv('kindle_reviews.csv')
print(data2.columns)
#remove uneccessary columns 
data2 = data2.drop(['Unnamed: 0', 'asin', 'helpful', 'overall','reviewTime', 
        'reviewerID', 'reviewerName','unixReviewTime'], axis = 1)
print("Removed unecessary columns")
data2.rename(index = str, columns = {'summary':'Summary', 'reviewText':'Text'}, inplace = True)
data2 = data2[['Summary','Text']]
# print(data2.head())
for i in range(5):
  print(data2.Text[i])
  print(data2.Summary[i])
  print('\n')
# Out:
# Index(['Unnamed: 0', 'asin', 'helpful', 'overall', 'reviewText', 'reviewTime',
#        'reviewerID', 'reviewerName', 'summary', 'unixReviewTime'],
#       dtype='object')
# Removed unecessary columns
# I enjoy vintage books and movies so I enjoyed reading this book.  The plot was unusual.  Don't think killing someone in self-defense but leaving the scene and the body without notifying the police or hitting someone in the jaw to knock them out would wash today.Still it was a good read for me.
# Nice vintage story
#
#
# This book is a reissue of an old one; the author was born in 1910. It's of the era of, say, Nero Wolfe. The introduction was quite interesting, explaining who the author was and why he's been forgotten; I'd never heard of him.The language is a little dated at times, like calling a gun a &#34;heater.&#34;  I also made good use of my Fire's dictionary to look up words like &#34;deshabille&#34; and &#34;Canarsie.&#34; Still, it was well worth a look-see.
# Different...
#
#
# This was a fairly interesting read.  It had old- style terminology.I was glad to get  to read a story that doesn't have coarse, crasslanguage.  I read for fun and relaxation......I like the free ebooksbecause I can check out a writer and decide if they are intriguing,innovative, and have enough of the command of Englishthat they can convey the story without crude language.
# Oldie
#
#
# I'd never read any of the Amy Brewster mysteries until this one..  So I am really hooked on them now.
# I really liked it.
#
#
# If you like period pieces - clothing, lingo, you will enjoy this mystery.  Author had me guessing at least 2/3 of the way through.
# Period Mystery

# %%
data = pd.concat([data2, data1])
print(data.head())
# Out:
#               Summary                                               Text
# 0  Nice vintage story  I enjoy vintage books and movies so I enjoyed ...
# 1        Different...  This book is a reissue of an old one; the auth...
# 2               Oldie  This was a fairly interesting read.  It had ol...
# 3  I really liked it.  I'd never read any of the Amy Brewster mysteri...
# 4      Period Mystery  If you like period pieces - clothing, lingo, y...

# %%
#checking for any empty data
print("Checking for empty data: ")
print(data.isnull().sum())
print('\n')
#remove any empty data 
data = data.dropna()
data = data.reset_index(drop = True)

#checking if the empty data has been deleted
print("Checking again for empty data: ")
print(data.isnull().sum())

print(data.head())
# Out:
# Checking for empty data:
# Summary    28
# Text       22
# dtype: int64
#
#
# Checking again for empty data:
# Summary    0
# Text       0
# dtype: int64
#               Summary                                               Text
# 0  Nice vintage story  I enjoy vintage books and movies so I enjoyed ...
# 1        Different...  This book is a reissue of an old one; the auth...
# 2               Oldie  This was a fairly interesting read.  It had ol...
# 3  I really liked it.  I'd never read any of the Amy Brewster mysteri...
# 4      Period Mystery  If you like period pieces - clothing, lingo, y...

# %%
#expand common contractions inside the text
contraction_expander = { 
"ain't": "am not", "aren't": "are not", "can't": "cannot", "can't've": "cannot have", "'cause": "because", "could've": "could have", "couldn't": "could not",
"couldn't've": "could not have", "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hadn't've": "had not have", "hasn't": "has not",
"haven't": "have not", "he'd": "he would", "he'd've": "he would have","he'll": "he will", "he's": "he is", "how'd": "how did", "how'll": "how will","how's": "how is",
"i'd": "i would","i'll": "i will","i'm": "i am","i've": "i have", "isn't": "is not","it'd": "it would","it'll": "it will","it's": "it is","let's": "let us","ma'am": "madam",
"mayn't": "may not","might've": "might have","mightn't": "might not","must've": "must have","mustn't": "must not","needn't": "need not","oughtn't": "ought not","shan't": "shall not",
"sha'n't": "shall not","she'd": "she would", "she'll": "she will","she's": "she is","should've": "should have","shouldn't": "should not","that'd": "that would", "that's": "that is",
"there'd": "there had","there's": "there is","they'd": "they would","they'll": "they will", "they're": "they are","they've": "they have","wasn't": "was not","we'd": "we would",
"we'll": "we will","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what're": "what are","what's": "what is", "what've": "what have",
"where'd": "where did","where's": "where is","who'll": "who will","who's": "who is", "won't": "will not","wouldn't": "would not","you'd": "you would","you'll": "you will",
"you're": "you are"
}

# %%
#function to clean the text and summary
stop_words = set(stopwords.words('english')) 
def content_cleaner(content, remove_stop_words=True):
    text = content.lower()

    #expand the contractions
    expanded_form = []
    for i in text.split():
      if i in contraction_expander:
        expanded_form = expanded_form + [contraction_expander[i]]
      else:
        expanded_form = expanded_form + [i]
    text = ' '.join(expanded_form)

    #remove the punctuations
    regex = re.compile('[%s]' % re.escape(string.punctuation))         
    text = regex.sub(" ", text)
    
    #whitespace
    text = re.sub('\s+', ' ', text).strip()  

    #stopwords removal
    if remove_stop_words:
        remove = [i for i in text.split() if not i in stop_words]  
        text = (" ".join(remove)).strip()

    return text

#clean the text and append into an array
clean_texts = []
for text in data.Text:
    clean_texts.append(content_cleaner(text,remove_stop_words=True))
print("Text Appended.")

#clean the summary and append into an array
clean_summaries = []
for summary in data.Summary:
    clean_summaries.append(content_cleaner(summary,remove_stop_words=False))
print("Summaries Appended.")

#checking 
for i in range(3):
  print("Text:\n", clean_texts[i])
  print("Summary:\n", clean_summaries[i])
# Out:
# Text Appended.
# Summaries Appended.
# Text:
#  enjoy vintage books movies enjoyed reading book plot unusual think killing someone self defense leaving scene body without notifying police hitting someone jaw knock would wash today still good read
# Summary:
#  nice vintage story
# Text:
#  book reissue old one author born 1910 era say nero wolfe introduction quite interesting explaining author forgotten would never heard language little dated times like calling gun 34 heater 34 also made good use fire dictionary look words like 34 deshabille 34 34 canarsie 34 still well worth look see
# Summary:
#  different
# Text:
#  fairly interesting read old style terminology glad get read story coarse crasslanguage read fun relaxation like free ebooksbecause check writer decide intriguing innovative enough command englishthat convey story without crude language
# Summary:
#  oldie

# %%
#see the distirbution
def distribution_length(text):
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

lengths_summaries = distribution_length(clean_summaries)
lengths_texts = distribution_length(clean_texts)

print("Describe Summaries:")
print(lengths_summaries.describe())
print('\n')
print("Describe Texts:")
print(lengths_texts.describe())
# Out:
# Describe Summaries:
#              counts
# count  1.551023e+06
# mean   2.211637e+01
# std    1.479597e+01
# min    0.000000e+00
# 25%    1.200000e+01
# 50%    1.800000e+01
# 75%    2.900000e+01
# max    2.490000e+02
#
#
# Describe Texts:
#              counts
# count  1.551023e+06
# mean   3.314817e+02
# std    3.977787e+02
# min    0.000000e+00
# 25%    1.080000e+02
# 50%    1.930000e+02
# 75%    3.830000e+02
# max    1.490900e+04

# %%
#checking lengths
count_text = 0
for i in clean_texts:
    if(len(i.split()) >= 10):
        count_text = count_text + 1
print("Minimum Text: ")
print(count_text/len(clean_texts))

count_summary = 0
for i in clean_summaries:
    if(len(i.split()) >= 5):
        count_summary = count_summary + 1
print("Minimum Summary: ")
print(count_summary/len(clean_summaries))
            
count_text = 0
for i in clean_texts:
    if(len(i.split()) <= 100):
        count_text = count_text + 1
print("Maximum Text: ")
print(count_text/len(clean_texts))

count_summary = 0
for i in clean_summaries:
    if(len(i.split()) <= 8):
        count_summary = count_summary + 1
print("Maximum Summary: ")
print(count_summary/len(clean_summaries))
# Out:
# Minimum Text:
# 0.9702377076290938
# Minimum Summary:
# 0.3366887531648467
# Maximum Text:
# 0.8796916615678814
# Maximum Summary:
# 0.9253931115141426

# %%
#place limitations on data due to computational limitations
minimum_text_length = 10
maximum_text_length = 100
minimum_summary_length = 3
maximum_summary_length = 8

#arrays to store summaries & texts that fit the requirements
accepted_summaries = []
accepted_texts = []

for i in range(len(clean_texts)):
  if(len(clean_summaries[i].split())>=minimum_summary_length and len(clean_summaries[i].split())<=maximum_summary_length and
        len(clean_texts[i].split()) >=minimum_text_length and len(clean_texts[i].split())<=maximum_text_length ):
    accepted_summaries.append(clean_summaries[i])
    accepted_texts.append(clean_texts[i])

#length of summaries and text
print("Summaries:", len(accepted_summaries))
print("Text:", len(accepted_texts))
# Out:
# Summaries: 770612
# Text: 770612

# %%
#see the distirbution of the accepted text and summaries
lengths_accepted_summaries = distribution_length(accepted_summaries)
lengths_accepted_texts = distribution_length(accepted_texts)

print("Describe Summaries:")
print(lengths_accepted_summaries.describe())
print('\n')
print("Describe Texts:")
print(lengths_accepted_texts.describe())
# Out:
# Describe Summaries:
#               counts
# count  770612.000000
# mean       24.158857
# std         8.893600
# min         5.000000
# 25%        17.000000
# 50%        23.000000
# 75%        30.000000
# max        77.000000
#
#
# Describe Texts:
#               counts
# count  770612.000000
# mean      238.107431
# std       149.711506
# min        27.000000
# 25%       118.000000
# 50%       194.000000
# 75%       323.000000
# max       830.000000

# %%
# Add tokens at the begining and the end of the summaries
accepted_summaries = list(map(lambda x: 'starttoken '+ x + ' endtoken', accepted_summaries))

# %%
text_train,text_val,summary_train, summary_val = train_test_split(np.array(accepted_texts),np.array(accepted_summaries), test_size = 0.2, random_state=0)
#tokenizer for text 
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(text_train))

count = 0
for i in x_tokenizer.word_counts.items():
  count = count + 1

#tokenizer for text 
x_tokenizer = Tokenizer(num_words = count)
x_tokenizer.fit_on_texts(list(text_train))

#convert text sequences into integer sequences
text_train = x_tokenizer.texts_to_sequences(text_train)
text_val = x_tokenizer.texts_to_sequences(text_val)

#ensures all sequences in the list have the same length
text_train = pad_sequences(text_train, maxlen = maximum_text_length, padding='post')
text_val = pad_sequences(text_val, maxlen = maximum_text_length, padding='post')

x_vocab = x_tokenizer.num_words + 1

# #tokenizer for summary
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(summary_train))

count = 0
for i in y_tokenizer.word_counts.items():
  count = count + 1

y_tokenizer = Tokenizer(num_words = count)
y_tokenizer.fit_on_texts(list(summary_train))

#convert text sequences into integer sequences
summary_train = y_tokenizer.texts_to_sequences(summary_train)
summary_val = y_tokenizer.texts_to_sequences(summary_val)

#padding zero upto maximum length
summary_train = pad_sequences(summary_train, maxlen = maximum_summary_length, padding='post')
summary_val = pad_sequences(summary_val, maxlen = maximum_summary_length, padding='post')

y_vocab = y_tokenizer.num_words + 1

# %%
#read glove word embeddings
embeddings_index = {}
f = open('glove.6B.100d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

word_index = x_tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
#taken from third party attention layer
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
    """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                  shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                  initializer='uniform',
                                  trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                  shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                  initializer='uniform',
                                  trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                  shape=tf.TensorShape((input_shape[0][2], 1)),
                                  initializer='uniform',
                                  trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

#model building
K.clear_session()
latent_dim = 500

#Encoder 
encoder_inputs = Input(shape = (maximum_text_length,))

#embedding layer
encoder_embedding = Embedding(x_vocab, 100, weights=[embedding_matrix],input_length=maximum_text_length, trainable=False)(encoder_inputs) 

#LSTM 1
encoder_lstm1 = LSTM(latent_dim, return_sequences=True, return_state=True)
encoder_output1, state_h1, state_c1 = encoder = encoder_lstm1(encoder_embedding)

#LSTM 2
encoder_lstm2 = LSTM(latent_dim, return_sequences=True, return_state=True,recurrent_dropout=0.3)
encoder_output2, state_h2, state_c2 = encoder = encoder_lstm2(encoder_output1)

#LSTM 3
encoder_lstm3 = LSTM(latent_dim, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder = encoder_lstm3(encoder_output2)

#Set up decoder
decoder_inputs = Input(shape=(None,))

#embedding layer
decoder_embedding_layer = Embedding(y_vocab, latent_dim, trainable = True)
decoder_embedding = decoder_embedding_layer(decoder_inputs)

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences = True, return_state = True)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(decoder_embedding, initial_state = [state_h, state_c])

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

#Concat attention output and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs,attn_out])

#Dense Layer
decoder_dense = TimeDistributed(Dense(y_vocab, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 100, 100)     16325900    input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 100, 500), ( 1202000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 100, 500), ( 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    23504000    input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 100, 500), ( 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 47008)  47055008    concat_layer[0][0]
# ==================================================================================================
# Total params: 94,593,408
# Trainable params: 78,267,508
# Non-trainable params: 16,325,900
# __________________________________________________________________________________________________

# %%
#compile and run model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

history=model.fit([text_train,summary_train[:,:-1]], summary_train.reshape((summary_train.shape[0],summary_train.shape[1], 1))[:,1:] ,epochs=3,callbacks=[early_stopping],batch_size=512, validation_data=([text_val,summary_val[:,:-1]], summary_val.reshape(summary_val.shape[0],summary_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/3
# 1205/1205 [==============================] - 1176s 976ms/step - loss: 3.5943 - val_loss: 3.1399
# Epoch 2/3
# 1205/1205 [==============================] - 1175s 975ms/step - loss: 2.9594 - val_loss: 2.8841
# Epoch 3/3
# 1205/1205 [==============================] - 1174s 974ms/step - loss: 2.7628 - val_loss: 2.7748

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# dictionary to convert the index to word 
reverse_summary_word_index=y_tokenizer.index_word
reverse_text_word_index=x_tokenizer.index_word
summary_word_index=y_tokenizer.word_index

# %%
#Inference
#Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

#Decoder 
#hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(maximum_text_length,latent_dim))

#embeddings of the decoder sequence
decoder_embedding2= decoder_embedding_layer(decoder_inputs) 
#setting initial states to the states from the previous time step for predicting next word
decoder_outputs2, state_h2, state_c2 = decoder_lstm(decoder_embedding2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense final output layer (softmax)
# generate prob distribution over the summary vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c], [decoder_outputs2] + [state_h2, state_c2])

# %%
def predicted(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    sequence = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    sequence[0, 0] = summary_word_index['starttoken']

    quitt = False
    predicted_summary = ''
    while not quitt:
      
        output_tokens, h, c = decoder_model.predict([sequence] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_summary_word_index[sampled_token_index]
        
        if(sampled_token!='endtoken'):
            predicted_summary += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'endtoken'  or len(predicted_summary.split()) >= (maximum_summary_length-1)):
            quitt = True

        # Update the target sequence (of length 1).
        sequence = np.zeros((1,1))
        sequence[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return predicted_summary

# %%
def summary(summary):
    original_sum = ''
    for i in summary:
        if((i!= 0 and i!= summary_word_index['starttoken']) and i!= summary_word_index['endtoken']):
            original_sum = original_sum + reverse_summary_word_index[i]+' '
    return original_sum

def text(text):
    original_text = ''
    for i in text:
        if(i!=0):
            original_text = original_text + reverse_text_word_index[i]+' '
    return original_text

for i in range(15):
  print("#",i+1)
  print("Text:",text(text_val[i]))
  print("Original summary:",summary(summary_val[i]))
  print("Predicted summary:",predicted(text_val[i].reshape(1,maximum_text_length)))
  print("\n")
# Out:
# # 1
# Text: delicious cookies cancelled subscription hope price comes back buy best ginger snaps found far price much
# Original summary: whoa that is quite a price increase
# Predicted summary:  great ginger chips
#
#
# # 2
# Text: price would say green tea tastes superb usually drink green tea honey sweeteners tea perfect tastes great would recommend anyone likes green tea wants relatively cheap box set
# Original summary: great tasting green tea
# Predicted summary:  good green tea
#
#
# # 3
# Text: think best gluten free cookies tried pamela mini cookies also good recipe back cookie crust desserts tried ginger snap crust little much ginger delicate tasting filling next time try using less crumbs sprinkle little topping tried chocolate cookies dessert crust yet ate 6 bag case fast
# Original summary: extremely good cookies
# Predicted summary:  good gluten free cookies
#
#
# # 4
# Text: book hard put enjoyed relationship h h friends family would want ryan good looking fighter pilot southern charm cass girl next door pretty smart may even sex scenes hot yet fun dressing role play looking forward books author
# Original summary: wow an officer and a gentleman 2013
# Predicted summary:  a good read
#
#
# # 5
# Text: devil contract hot like 34 holy crap claire knew could write sexy like hot 34 also mysterious filled suspense kept guessing wondering every twist turn 34 wonder 34 34 34 going head loved every minute love way claire writing always keeps toes
# Original summary: claire is a must read
# Predicted summary:  hot hot hot
#
#
# # 6
# Text: hoping precise suggestions says could could helpful suggesting add wall shelving removable stackable drawers papers call helpful organization solutions thought would include filing system instead telling make one kindle fire version
# Original summary: hoped for more
# Predicted summary:  good basic info
#
#
# # 7
# Text: book exciting thought going heroine book stubborn dramatic almost made want stop reading every predicament got continued reading loved hero brant alhough book predicatable begining could help drawn wonder men like fall love women like happens reality happen book like way book ended needed epilogue type follow brant home money going live going eat could sunshine rainbows left cave want light read something requires complexity great book read
# Original summary: not as exciting as i thought
# Predicted summary:  a good read
#
#
# # 8
# Text: came across short story first anthology story sure spooky enjoyed chills much read novel accompanies short story loved
# Original summary: haunting excellent read
# Predicted summary:  short and sweet
#
#
# # 9
# Text: series written 100 years ago interesting read tom swift language somewhat stilted actions interesting something think day age fun casual reading
# Original summary: books of the early 1900s
# Predicted summary:  fun fun read
#
#
# # 10
# Text: really enjoyed books really kept going want put really knows make mad bad guy fall love good guys would recommend anyone likes love stories read two books
# Original summary: fate interrupted 1 2
# Predicted summary:  i loved it
#
#
# # 11
# Text: first new fan passed amazon recommendations years would read work wanted classic happily ever afters well decided read afterwards baby hooked characters flippin real smell sweat feel tears shake many climaxes book continuation mistress characters keisha jay ever evolving prevailed adversities challenged better nobody super rich beautiful yet flawed frail people want better true love story ms forrester wonderfully talented author makes true love seem like reality instead usual fantasy bravo cannot wait wife released
# Original summary: an excellent read
# Predicted summary:  a great read
#
#
# # 12
# Text: enjoyed riley chelle say one little drawn problem books major conflict riley reasons wanting manufactured would man spent 12 years marine recon guy really think still bad guy stupid teen honestly think brother still overbearing prick almost 30 little ridiculous would assume like bi polar mother never exhibited symptoms however relationship b w riley chelle sweet hot really like roll give douche fiance drops bombshell katie wedding strong heroine riley great except stupid reasons thinking good enough know sounds like like much jason katie could internal monologues shortened cut much better going keep going series
# Original summary: another good one
# Predicted summary:  a good start
#
#
# # 13
# Text: generally like cereal little less sugar add sweetener want otherwise good flake type cereal good quantity fiber little low protein compared cereal people generally add protein using milk add choice fruit usually like combination sliced banana strawberries sometimes add blueberries
# Original summary: one of the better high fiber cereals
# Predicted summary:  good cereal but
#
#
# # 14
# Text: awesome romantic series set small town really get know everyone town cross paths lots love sad times naughty ones 128521
# Original summary: check it out
# Predicted summary:  love this series
#
#
# # 15
# Text: love case good quality great price good colors choose would highly recommend product
# Original summary: kindle fire case
# Predicted summary:  great price and quality

# %%
for i in range(1000):
  print("#",i+1)
  print("Text:",text(text_val[i]))
  print("Original summary:",summary(summary_val[i]))
  print("Predicted summary:",predicted(text_val[i].reshape(1,maximum_text_length)))
  print("\n")
# Out:
# # 1
# Text: delicious cookies cancelled subscription hope price comes back buy best ginger snaps found far price much
# Original summary: whoa that is quite a price increase
# Predicted summary:  great ginger chips
#
#
# # 2
# Text: price would say green tea tastes superb usually drink green tea honey sweeteners tea perfect tastes great would recommend anyone likes green tea wants relatively cheap box set
# Original summary: great tasting green tea
# Predicted summary:  good green tea
#
#
# # 3
# Text: think best gluten free cookies tried pamela mini cookies also good recipe back cookie crust desserts tried ginger snap crust little much ginger delicate tasting filling next time try using less crumbs sprinkle little topping tried chocolate cookies dessert crust yet ate 6 bag case fast
# Original summary: extremely good cookies
# Predicted summary:  good gluten free cookies
#
#
# # 4
# Text: book hard put enjoyed relationship h h friends family would want ryan good looking fighter pilot southern charm cass girl next door pretty smart may even sex scenes hot yet fun dressing role play looking forward books author
# Original summary: wow an officer and a gentleman 2013
# Predicted summary:  a good read
#
#
# # 5
# Text: devil contract hot like 34 holy crap claire knew could write sexy like hot 34 also mysterious filled suspense kept guessing wondering every twist turn 34 wonder 34 34 34 going head loved every minute love way claire writing always keeps toes
# Original summary: claire is a must read
# Predicted summary:  hot hot hot
#
#
# # 6
# Text: hoping precise suggestions says could could helpful suggesting add wall shelving removable stackable drawers papers call helpful organization solutions thought would include filing system instead telling make one kindle fire version
# Original summary: hoped for more
# Predicted summary:  good basic info
#
#
# # 7
# Text: book exciting thought going heroine book stubborn dramatic almost made want stop reading every predicament got continued reading loved hero brant alhough book predicatable begining could help drawn wonder men like fall love women like happens reality happen book like way book ended needed epilogue type follow brant home money going live going eat could sunshine rainbows left cave want light read something requires complexity great book read
# Original summary: not as exciting as i thought
# Predicted summary:  a good read
#
#
# # 8
# Text: came across short story first anthology story sure spooky enjoyed chills much read novel accompanies short story loved
# Original summary: haunting excellent read
# Predicted summary:  short and sweet
#
#
# # 9
# Text: series written 100 years ago interesting read tom swift language somewhat stilted actions interesting something think day age fun casual reading
# Original summary: books of the early 1900s
# Predicted summary:  fun fun read
#
#
# # 10
# Text: really enjoyed books really kept going want put really knows make mad bad guy fall love good guys would recommend anyone likes love stories read two books
# Original summary: fate interrupted 1 2
# Predicted summary:  i loved it
#
#
# # 11
# Text: first new fan passed amazon recommendations years would read work wanted classic happily ever afters well decided read afterwards baby hooked characters flippin real smell sweat feel tears shake many climaxes book continuation mistress characters keisha jay ever evolving prevailed adversities challenged better nobody super rich beautiful yet flawed frail people want better true love story ms forrester wonderfully talented author makes true love seem like reality instead usual fantasy bravo cannot wait wife released
# Original summary: an excellent read
# Predicted summary:  a great read
#
#
# # 12
# Text: enjoyed riley chelle say one little drawn problem books major conflict riley reasons wanting manufactured would man spent 12 years marine recon guy really think still bad guy stupid teen honestly think brother still overbearing prick almost 30 little ridiculous would assume like bi polar mother never exhibited symptoms however relationship b w riley chelle sweet hot really like roll give douche fiance drops bombshell katie wedding strong heroine riley great except stupid reasons thinking good enough know sounds like like much jason katie could internal monologues shortened cut much better going keep going series
# Original summary: another good one
# Predicted summary:  a good start
#
#
# # 13
# Text: generally like cereal little less sugar add sweetener want otherwise good flake type cereal good quantity fiber little low protein compared cereal people generally add protein using milk add choice fruit usually like combination sliced banana strawberries sometimes add blueberries
# Original summary: one of the better high fiber cereals
# Predicted summary:  good cereal but
#
#
# # 14
# Text: awesome romantic series set small town really get know everyone town cross paths lots love sad times naughty ones 128521
# Original summary: check it out
# Predicted summary:  love this series
#
#
# # 15
# Text: love case good quality great price good colors choose would highly recommend product
# Original summary: kindle fire case
# Predicted summary:  great price and quality
#
#
# # 16
# Text: lord wicked interesting premise love idea hero suspected murdering first wife heroine well drawn admirable enjoyed reading story writing good
# Original summary: a nice read
# Predicted summary:  a fun read
#
#
# # 17
# Text: wonderful able eat pasta without guilt thank making product please stop making
# Original summary: love love love it
# Predicted summary:  great pasta and taste
#
#
# # 18
# Text: book thorough well written want give 4 stars probably deserves higher rating visual learner reading text often wished pictures diagrams entertainment fair though note text overly dry boring author thoughtfully included tips helpful hints glossary end needs pics
# Original summary: ok but needs pictures and
# Predicted summary:  good book for the beginner
#
#
# # 19
# Text: tuna best packed olive oil best cuts fish open go straight salad nicoise really wanted put tuna toast sprinkle balsamic vinegar either way smile
# Original summary: tuna at its best
# Predicted summary:  great tasting salmon
#
#
# # 20
# Text: going honest writing review read entire series series one book righting good compelled read honest like kinky sex books sex got cruel quite frankly end liking jonathan much romantic driven sexual needs end even though cried bit really hoped might die monica could hook sexy sweet nice doctor figure get beat sex really good bruises body come reading series really craved sweet romantic novel wash cruelty away surprised see women little bothered rough sex lack romance
# Original summary: entire series not romance just cruel sex
# Predicted summary:  not my favorite
#
#
# # 21
# Text: things used distracting suspected criminal using instead aliases suspected criminal never asked obtained multiple murder weapon descriptions dialogue fbi police excessive description minor characters always telling characters know see guess one definitely try author
# Original summary: lots of distractions
# Predicted summary:  a good story
#
#
# # 22
# Text: like truly good horror story much horrors mind comes inhumanity beyond elegant prose amongst best read genre story depravity depth almost unimaginable problem entirely real children one get title reading story great candidate outer limits particularly dark twilight zone episode dash robert tossed good measure nicole cushing writer watch read reread
# Original summary: deceptive elegant writing existential horror
# Predicted summary:  a dark horror story
#
#
# # 23
# Text: cat picky eater went many different brands flavors turned favorite every cat preferences best bet sample buying bulk pack like tried natural balance based recommendation healthier food natural ingredients packed fillers byproducts cat lost weight seems healthier overall since switching
# Original summary: good ingredients happy cat
# Predicted summary:  my cat loves this food
#
#
# # 24
# Text: adult maybe kid would like one could get past first pages moved onto another book free
# Original summary: would not recommend
# Predicted summary:  not my cup of tea
#
#
# # 25
# Text: admit cover free book reasons starting book great story kept reading little bit something everyone suspense angst darkness sweetness paranormal elements love looking forward next book
# Original summary: enjoyed this story
# Predicted summary:  a great read
#
#
# # 26
# Text: captivating treasure cover cover first word last hayley aiden amazing joy read 8217 praise book highly enough thrilling beautiful love story believable romance addictive character dynamics loved 8807 9684 9697 9684 8806 5 10032 read 8807 9673 9697 9673 8806 62 62 62 arc received exchange honest review 60 60 60
# Original summary: such a captivating treasure
# Predicted summary:  a beautiful story
#
#
# # 27
# Text: expecting sour gummies like troll gummi worms buy local stores nice soft sour dusted powdered sugar flavor anything close expected
# Original summary: not what i expected
# Predicted summary:  not as good as the others
#
#
# # 28
# Text: megan trish volunteer medical experiment could wipe disease known humans inadvertently get super powers change lives friends relations forever great premise novel comic book one well written emotional powerful fun suspenseful delightful almost impossible put friends get comfortable devour book
# Original summary: a fun delightful satisfying tale
# Predicted summary:  a fun read
#
#
# # 29
# Text: going take noni take pure noni one juice added read contained raspberry juice
# Original summary: contains raspberry juice
# Predicted summary:  not as good as the others
#
#
# # 30
# Text: best tea ice tea ever flavor smooth amber color beautiful never cloudy never bitter try red rose go back lipton someone slap
# Original summary: the best for ice tea
# Predicted summary:  best tea ever
#
#
# # 31
# Text: ritz crackers used favorite cracker loved buttery flavor little salt ended last box purchased crackers almost white half baked flavor except heavy salting gone golden color buttery flavor left white cracker heavy salt contacted kraft nabisco apparently thought complimenting sent back ads nabisco products flip apparently care quality product utterly gone use extreme caution purchasing product
# Original summary: ritz used to be my favorite
# Predicted summary:  not a fan
#
#
# # 32
# Text: wanted like story first problem previous reviewers mentioned much explanation need told character gets car opens door gets car closes door behind excruciating second problem enjoy story bare bones story 2 stars idea could good way done interesting
# Original summary: too much explanation
# Predicted summary:  a good story
#
#
# # 33
# Text: stumbled across book looking free books new authors took minute become familiar terms book set austrailia book well written look forward reading rest books series also went looked books jd nixon discovered heller series another great series definately read author puts
# Original summary: great new author
# Predicted summary:  a great read
#
#
# # 34
# Text: tried many gf bread mixes ready eat brands mix best also versatile forgiving made without eggs bread machine even though pkg cautions delicious grandson asked sure gluten free dairy free soy free gluten free diet best doubt
# Original summary: best gf bread mix ever
# Predicted summary:  gluten free bread mix
#
#
# # 35
# Text: glad went ahead ordered better expected another plus sent pump watch sugar free products company company favorites list
# Original summary: very very good
# Predicted summary:  splenda in the jar
#
#
# # 36
# Text: love love love russian protector series fighting connolly series particular book third fighting connolly series particular book evolving love story oldest brother jack lady abby book full emotional family dynamics plenty criminal activity diverted dispelled eagerly await next brother finn story also trying patiently wait new series especially continuation russian protector series thanks ms rivera entertaining novels please continue keep coming
# Original summary: another within series hit
# Predicted summary:  another great read
#
#
# # 37
# Text: timothy midnight magic far one best k cups tried sufficiently strong flavorful
# Original summary: one of the best k cups
# Predicted summary:  best k cup yet
#
#
# # 38
# Text: really enjoyed love story book friendship love family really shines enjoyable romantic story
# Original summary: second chance hero
# Predicted summary:  a sweet love story
#
#
# # 39
# Text: okay erotica romance novel enjoyed story get heroine grammar issues back forth story seemed kinda rushed enjoyed story line wish took little bit
# Original summary: i liked it
# Predicted summary:  not a romance
#
#
# # 40
# Text: read short story early morning hours coffee hand great fun ending nice twist suspect author knows bit funeral parlors
# Original summary: coffin humor was fun
# Predicted summary:  a fun read
#
#
# # 41
# Text: 12 year old sheltie chronic brochotitis meds three years help coughing fits night like br one bite dogs addicted warned 7 pm shelties lap howling drug fix dog trainer never seen anything like br br three weeks later beloved sheltie got bowel blockage use caution br cat gets many runs br sheltie better upped thryoid meds gave doggie asthma meds br worked better 18 year old cat also asthma
# Original summary: but works for night coughing in dogs
# Predicted summary:  greenies are great
#
#
# # 42
# Text: love bars dairy rice gluten free allergic fill keep going longer granola bars also taste delicious
# Original summary: nature valley granola bars
# Predicted summary:  gluten free granola
#
#
# # 43
# Text: peppercorns beautiful rosy color clues even get chance open package peppercorns known life pull open bag inhale aroma find combine scent pepper wonderful fruity almost floral overtone hard describe even harder imagine experienced lovely part flavor profile diminish use ground steeped sichuan peppercorns dark chocolate mousse grind finely steep heavy cream 30 minutes straining cream chocolate vibrant peppery fruit floral scent top note mousse memorably different flavor looking ways add dishes see new nuances impart old favorites
# Original summary: a bit different and wonderful
# Predicted summary:  a wonderful surprise
#
#
# # 44
# Text: type book usually like well written engaging grammatical errors interrupt flow story obvious attacked ruby crowbar ending still surprise
# Original summary: an engaging story
# Predicted summary:  good story but
#
#
# # 45
# Text: hesitant try first honestly eggnog love tea form sound appealing aunt kept telling us try unable find stores far year liked well enough order 6 pack amazon even subscribe delivered regular basis arrived shared us say quite delicious somewhat eggnog flavor almost mellow chai flavor lightly spiced vanilla good something different tea wise
# Original summary: nice lightly spiced tea
# Predicted summary:  not my favorite
#
#
# # 46
# Text: like regular raisin bran new version disappoint hint cinnamon overpowering definitely like almond clusters give cereal extra crunch added protein boost dramatically different regular raisin bran nice change pace
# Original summary: this is good
# Predicted summary:  not for me
#
#
# # 47
# Text: snack bar tastes really good cannot go wrong product good hide rest family price great
# Original summary: they are the yummiest snack
# Predicted summary:  healthy snack bar
#
#
# # 48
# Text: really sorry say hoping definitely different two series read catherine discourage following catherine getting books getting particular series book main character mitch gorgeous well established man janet main character nurse little adventure sexual attraction bantering fell flat solid building story yes really good areas book blotchy build overall delivery plus obvious going happen even though cannot really say one book would recommend would still highly recommend two series read called weekday brides quite series rocked
# Original summary: not one of my favorites from catherine
# Predicted summary:  a good start
#
#
# # 49
# Text: exciting thing missing comments made act referenced said would liked printed making erotic however delicious
# Original summary: excitement in the exploration
# Predicted summary:  not a fan
#
#
# # 50
# Text: excited pick vine program purchased new kindle fire hd really wanted protect investment seemed like good option amazing works perfectly leaving bubbles touch screen affected easy apply make sure screen free dust dirt fingerprints apply would recommend help keep kindle fire hd screen looking new scratch free
# Original summary: protect your investment
# Predicted summary:  great for the price
#
#
# # 51
# Text: saw item tv one tries eat healthy eat bacon often love saw calories thought godsend tried bad bacon blt definately blt salty think fine add little flavor cooking seemed salt bacon flavor excited get home try remained cabinet rarely used love bacon real bacon soups veggies
# Original summary: i love bacon
# Predicted summary:  not a bad texture
#
#
# # 52
# Text: nicely odd little tale erotic elements exactly erotica historical elements elements horror manages elude categories well author writing really graceful
# Original summary: strange and beautiful
# Predicted summary:  a good read
#
#
# # 53
# Text: bought husband christmas loves cook using different herbs grows herbs garden summer grow year round really pleased garden growing exactly said would reason give five light extremely bright moved around several times found suitable place guess plants need light way bright leave kitchen pleased item would buy
# Original summary: cute little garden
# Predicted summary:  great gift for a great price
#
#
# # 54
# Text: fairy tales disturbing dark could ever imagine cannot stop reading highly descriptive imaginative
# Original summary: absolute horrid story i really enjoyed it
# Predicted summary:  a dark fairy tale
#
#
# # 55
# Text: like item keeps screen clean clear wiped clean easy put useful
# Original summary: moshi ivisor xt hd clear
# Predicted summary:  good but not great
#
#
# # 56
# Text: purchased almonds enjoyed unfortunately purchased amazon disappointed nuts old limp tasteless opened bags sampled many nuts could believe whole six bags inedible e mailed company inquire expiration dates batch numbers could avoid getting bad old batch next time company ignored us amazon refunded money thank amazon apparently sunridge company care ship old nuts amazon warehouses waste hard earned money expensive old nuts
# Original summary: do not buy these old nuts
# Predicted summary:  stale almonds stale
#
#
# # 57
# Text: freeze dried liver treats easy carry around treat pouch refrigerated far know healthy high protein snacks without lot chemical additives preservatives attributes nice would important dog like dog gets lots small bite size treats part continuing training gets tired diced sausage shaped moist food pet store cut franks grocery run mile liver treat wish smaller less expensive usually cut quarters sharp knife make last longer
# Original summary: our dog loves them
# Predicted summary:  healthy treats for dogs
#
#
# # 58
# Text: interesting read found things plausible suspension disbelief pacing good stay night finish keep interested reading first installment purchase next great sign hope keeps going strong couple characters formulaic fits genre need someone route someone hate always moment realize character made decision usually wrong one fate sealed would recommend book
# Original summary: a good read
# Predicted summary:  a good read
#
#
# # 59
# Text: pros br visually appealing br sweet br limbs tasted bit like marshmallow pleasant surprise least br br cons well kind br kind wish fruitier tasty way alright br addictive br feel bad eating nice look br br overall would recommend br br seller super fast nice packaging
# Original summary: taste of marshmallow
# Predicted summary:  not what i expected
#
#
# # 60
# Text: cliff hanger conclusion would five stars david narcissistic psychopathic lunatic emma naive hot head could believe david felt emma different others really surely find next book
# Original summary: awesome erotic thriller
# Predicted summary:  a good read
#
#
# # 61
# Text: long fan tully kona blend coffee disappointed local retailer quit selling kona products br br actually ordered house blend accident thinking ordering kona blend 4 cups coffee noticed packaging said house blend instead kona blend would known kona blend seen packaging one caveat make lattes adding equal amount steamed milk coffee coffee flavor probably diluted someone drinking straight may notice difference flavor br br bottom line much less expensive kona blend due vendor shipping costs good enough since ordered another box
# Original summary: less expensive alternative to the kona blend
# Predicted summary:  weak coffee weak flavor
#
#
# # 62
# Text: woah book full hot sex actually one extended sex scene really sex terrible thing opinion men hot leading lady intelligent classy easy synergy everyone means pointless distraction action heroine given couple challenges conflicts minor quickly resolved deep plots characters times interested would recommend book times wanting wanting hot sexy read
# Original summary: do not read this book in public
# Predicted summary:  hot hot hot
#
#
# # 63
# Text: great new twist love story first couple paragraphs rough get writing smoothed found feet ride went great story
# Original summary: very interesting read
# Predicted summary:  great story but
#
#
# # 64
# Text: little ones love seaweed rice seaweed disappoint br brands oily salty enough one though right br would buying
# Original summary: seaweed and rice
# Predicted summary:  not for me
#
#
# # 65
# Text: cant describe much love book actually hurt tyrian author weave story like nothing ever read well worth every minute great job vl moon radar
# Original summary: cheering tyrian on
# Predicted summary:  i am hooked on this author
#
#
# # 66
# Text: read jcp books loved youve got get one jcp one automatic buys highly recommend
# Original summary: another awesome read
# Predicted summary:  i love this book
#
#
# # 67
# Text: like bars strangely really taste like chocolate orange strong orange smell like concentrated orange oil orange extract lots orange zest zest like flavor quite orange chocolate like weird guess moist dense cannot beat unctuous quality snack feels naughty fills yet healthy natural actually good starting really like larabars hope try flavors
# Original summary: jocolat chocolate orange bar
# Predicted summary:  not a good snack
#
#
# # 68
# Text: need chloe 60 pages every months enough need beam fos stories intertwine well cannot even begin explain lexi adds nasty wet tongue world beam creating home crave smut philosophy sci fi stories conjoined twins bound hip gyrating pleasure
# Original summary: god this is a fantastic tie in
# Predicted summary:  a great read
#
#
# # 69
# Text: book stands shoulder shoulder another favorite book lord got free love thanks kathryn
# Original summary: another favorite from this author
# Predicted summary:  a great read
#
#
# # 70
# Text: grew south 50 fondest memories turbulent times saturday breakfast consisting bacon salt pork sausage country ham biscuits brer rabbit syrup choice blue label brown label going order try eat much longer child try ingest much sugar oh love stuff
# Original summary: best syrup ever
# Predicted summary:  the best of the best
#
#
# # 71
# Text: big black lab eats anything gusto beggin strips size package subscribe order regular basis price cannot beaten
# Original summary: my hound loves these things
# Predicted summary:  good for small dogs
#
#
# # 72
# Text: story could longeri would liked interactions two maybe third part honest part one two could combined
# Original summary: nice read but too short
# Predicted summary:  it was ok
#
#
# # 73
# Text: green mountain coffee nice robust flavor strong weak tell made better quality coffee beans would highly reccomend coffee friends family would buy coffee
# Original summary: a great cup of coffee
# Predicted summary:  good coffee strong coffee
#
#
# # 74
# Text: 68 pages author scratched surface subject matter trying say dont know mr reese however wonder medical backround write book like broken information show sources findings would say e book short primer needs fleshed also mr reese needs show backround expert writing book basic overview subject matter seem informative maybe wrote larger detailed volume f theories happens
# Original summary: a primer on phobias
# Predicted summary:  not worth the money
#
#
# # 75
# Text: expected gain insights nutrition general health maintenance book deliver gems scattered book dr philosophy help either much information outdated significant medical advances occurred since interviews conducted looking practical guide application nutrition healing wisdom little make book worth reading
# Original summary: little of practical value
# Predicted summary:  good book for the beginner
#
#
# # 76
# Text: bought nice strong tea flavor mix half half twinings english breakfast tea nice orange flavor could use little stronger tea flavor go try think may like way tried lipton celestial teas strong orange flavor
# Original summary: good but needs a little kick
# Predicted summary:  good tea but
#
#
# # 77
# Text: somehow expected reading summary quick entertaining read enjoyed male lead little conveniently perfect taking everything heroine said faith pretty much day one relations decidedly uncomplicated storyline interesting book well paced enjoyed unfolding mystery never distracted annoyed editing errors bad writing etc good choice looking light pleasant mystery
# Original summary: not what i expected
# Predicted summary:  a good read
#
#
# # 78
# Text: would first time reading author must say good book making good book drama suspense murder could put read one day v brown reconsidered good good black ice
# Original summary: the page turner
# Predicted summary:  a good read
#
#
# # 79
# Text: first box ever bought good tea tasted better cold hot would make ice tea refrigerate wanted last boxes bought however awful would boil water steep tea would make oily film top would float tasty drink know sometimes plants oils excessive killed flavor buying brand
# Original summary: i liked it at first
# Predicted summary:  tastes like plastic
#
#
# # 80
# Text: used keeps getting leg cramps used several years find dieting tend get leg cramps night taking nightly completly stops
# Original summary: calm it works
# Predicted summary:  calm plus calcium
#
#
# # 81
# Text: kathleen ball always pens perfect hunky cowboy hero feisty heroine throws heartwarming heart wrenching plots suck keep page page winter embrace exception stone books trip winter cruise line winter choice ignore pain emotions presence brings things take turn worse stone comes rescue realizes may using come rescue winter find truth behind stone feelings let many twists kathleen ball weaves throughout story line keep edge seat beautiful story looking forward final book cowboy seasons series
# Original summary: another beautiful story with a surprising twist
# Predicted summary:  a wonderful read
#
#
# # 82
# Text: tim burton unique vision almost cartoonish times really comes across film dark comedy accents humor rather horror also noteworthy michael keaton character annoying living dead well winona ryder character also interesting watch
# Original summary: 1988 tim burton film dvd
# Predicted summary:  a fun read
#
#
# # 83
# Text: natural eating living much possible finding herbs fascinated recently learned using dandelions salads smoothies yet learned even lee great recipes get great herbs diet book well formatted easy navigate table contents plus highly recommended
# Original summary: loved this book
# Predicted summary:  great book for healthy health
#
#
# # 84
# Text: take two highly addictive irresistible loved finished matter hours could put captivated laurelin captivating flawless writing style way crafted characters angsty scorching hot romantic story absolute must read 8807 9684 9697 9684 8806 5 10032 read 8807 9673 9697 9673 8806 62 62 62 arc received exchange honest review 60 60 60
# Original summary: angsty scorching hot and so romantic story
# Predicted summary:  a must read
#
#
# # 85
# Text: one favorite flavored coffees caramel flavor nice smooth syrupy tasting like coffee shop adds syrup regular coffee give certain flavor coffee drinkers individual tastes wife coffee delicious br br important carefully check price order coffee seller box 24 cups cost less fourteen dollars exclusive shipping discounts available order multiple boxes including free shipping google name coffee find various sites keurig buy mine coffee available
# Original summary: delicious flavored coffee
# Predicted summary:  great coffee great price
#
#
# # 86
# Text: pretty tame compared books gavin carrie ok ending course read books continue story
# Original summary: action thriller it is not
# Predicted summary:  not a good read
#
#
# # 87
# Text: holy crap really smutty sexy shifter book already read second book series also short amount smut
# Original summary: so much smut
# Predicted summary:  hot and sexy
#
#
# # 88
# Text: good read disappoint big giving away spoilers read 2 books per day choosey pickings book 5 star worthy
# Original summary: very good read
# Predicted summary:  good book but
#
#
# # 89
# Text: years using splenda parents wanted change tried truvia friends place loved changed truvia ever since
# Original summary: mom n dad love it
# Predicted summary:  best sugar substitute
#
#
# # 90
# Text: keeps getting better officially hooked shifter series sweet taste romance tigers intrigue nobody paranormal suspense quite like dawn steele plenty things happening latest installment left guessing romance rust kate started earlier facing greatest challenge yet hot alpha shifter rust plunged murder mystery may prime suspect wonderful subplot story made read like romantic mystery novel course real star show steamy love characters tensions heat hearts ms steele delivers another enthralling story high emotional danger steamy moments always enjoyed way steele crafts shifter characters paranormal myths one favorite five star reads far summer
# Original summary: an a mystery paranormal romance
# Predicted summary:  a great read
#
#
# # 91
# Text: book begins author story massive debt bankruptcy climbing sincere story allows readers feel like sitting good friend give advice rather know financial planner recommend book anyone getting concerned debt regardless whether crisis
# Original summary: help for folks being swallowed by debt
# Predicted summary:  a great book for everyone
#
#
# # 92
# Text: never experienced good coffee drinking coffee ever since got keurig coffee pot 2 years ago great
# Original summary: best coffee in town
# Predicted summary:  great coffee great price
#
#
# # 93
# Text: pagodas great cooked shells totally fell apart even done yet
# Original summary: not loving the shells
# Predicted summary:  not as good as the first
#
#
# # 94
# Text: wanted woman far distant past magic humanity compassion world misguided love story character hope grow book well written acceptable errors transcription editing unfortunately took away story look foreward reading comes next
# Original summary: the pendragon chronicles love it
# Predicted summary:  a good story
#
#
# # 95
# Text: craig gave opportunity read biography life knocks post honest review sure going find outside normal genre however started reading disappointed tried something new life knocks tells story colossus sosloss craig adventures goes life quite frankly however amount drug alcohol use described small miracle craig grey matter left write brilliantly entertaining novel laughed cried along craig told us story love life loss times wanted skip tales present immersed stories told time lily times questioned sanity especially describes harrowing situations comedic form could possibly lived landlord without killing night true wonder recommend book anybody wants loose amazing life
# Original summary: life love and loss
# Predicted summary:  a great read
#
#
# # 96
# Text: waffle sandwiches become favorite suppers family thought could get ideas book nice recipes making waffles however recipes titled 34 outta world chicken waffle recipe 1 34 34 outta world chicken waffle recipe 2 34 get idea make never remember one liked wont remember 1 11 content page hyperlinked nice feature pictures able use imagination reading novel cookbook
# Original summary: enjoyed this book
# Predicted summary:  great gluten free recipes
#
#
# # 97
# Text: bars taste fine problem condition product sent back bars stuck perhaps melted plastic wrapper removed scraping small individual pieces ordered cranberry almond bars along kind apricot almond mango macadamia nut bars flavors came different seller arrived great condition even though sent shipment defective box bother hassle attempting return especially since ate one bars realized problem entire box real waste money
# Original summary: product arrived in poor condition
# Predicted summary:  stale and stale
#
#
# # 98
# Text: purchased book house cluttered need work well disappointed little book got inside tricks tips could imagined learn remove rust stains clean mattresses bad odors coffee makers much also learn remove skunk spray clean septic tank using yeast plenty tips disappointed handy guide offers much use vacuum cleaner properly ha great little book kudos author coming great tips never would thought
# Original summary: tips galore very handy guide
# Predicted summary:  good book for the beginner
#
#
# # 99
# Text: commitment quality outstanding silken teabags contain high quality teas bags elegant staples teabags looks great makes bags microwaveable br br develop preference favorite tea recommend buying 50pc 5 gram triangle silken bags also staples tea used even higher quality
# Original summary: great taste and quality
# Predicted summary:  great value and quality
#
#
# # 100
# Text: z latin phrases translated english never knew little latin know scrolling helpful manual going start incorporating latin everyday vocabulary thanks author dr harry jay pronunciation another issue another book expand mind download book
# Original summary: latin to english
# Predicted summary:  good book for the beginner
#
#
# # 101
# Text: short good read love good romance bringing two people together together fighting make
# Original summary: short but good
# Predicted summary:  a good read
#
#
# # 102
# Text: love product like flavors one best like mashed potatoes chip hard eat whole bag let tell least healthier options could find favorite flavor area though found flavors sour cream onion cheddar barbeque original favorite went route could happier yum chips get
# Original summary: salt pepper popchips are the best
# Predicted summary:  popchips are the best
#
#
# # 103
# Text: nice strong coffee works well mocha machine could make coffee creamy hand though
# Original summary: good italian coffee
# Predicted summary:  good coffee good price
#
#
# # 104
# Text: book enjoyable far enjoying grant stevens series would recommend anyone enjoys action
# Original summary: enjoyed this book
# Predicted summary:  a good read
#
#
# # 105
# Text: often reviews love brown sauce happy amazon ship turned friends one friends puts tuna fish pouch kind never england ireland would like try sauce closest get describe spicy ketchup better think bbq sauce put fries rice burgers steaks eggs apparently good fish
# Original summary: i lt 3 brown sauce
# Predicted summary:  great sauce for a great price
#
#
# # 106
# Text: tea lovely flavor good ratio black tea rose petals rose flavor strong adds floral lightness tea reminds lady grey bag seals well tea smelled fresh arrived shipping prompt
# Original summary: high quality and affordable
# Predicted summary:  great tea for a tea
#
#
# # 107
# Text: finished book far want stop reading characters never really connected like constant make break thing got bit old awhile
# Original summary: it was okay
# Predicted summary:  not my cup of tea
#
#
# # 108
# Text: absolutely seriously loved loved loved mention loved book born raised nc visit isle every fall made book little amazing lol beautiful story loved every second finished within day wow cannot wait chelsea camaron
# Original summary: oh my one ride is not enough
# Predicted summary:  loved this book
#
#
# # 109
# Text: book well written exciting characters flawed humans made mistakes learned would like explore older sister life another exciting book recommend book wholeheartedly
# Original summary: very good read
# Predicted summary:  a great read
#
#
# # 110
# Text: great drink shame discontinued nestles always enjoyed taste always refreshing drink
# Original summary: a great refreshing drink
# Predicted summary:  refreshing refreshing refreshing
#
#
# # 111
# Text: pre teen young teen nieces enjoyed ghost story others much may stopping lot could translate british phrases stories might enjoyed slightly older teens
# Original summary: good for younger readers
# Predicted summary:  not my cup of tea
#
#
# # 112
# Text: book cover tells us coconut oil nature miracle information book certainly many benefits come use coconut oil weight loss one hair complexion much book well organised even includes listing 100 uses celebrities favour use informative helpful read
# Original summary: benefits of coconut oil
# Predicted summary:  good book for coconut oil
#
#
# # 113
# Text: review title pretty much says love brad taylor books involving taskforce even though pike really cannot good
# Original summary: simply great once again
# Predicted summary:  a good read
#
#
# # 114
# Text: especially anyone feels blue holiday tale warm heart even hope love seems lost feel possibly found grab cup cocoa curl couch
# Original summary: a feel good holiday tale
# Predicted summary:  a christmas story
#
#
# # 115
# Text: still really compare genuine theater popcorn bad overall bit salty many unpopped kernels compared mega pop almost cannot beat real thing theater
# Original summary: not bad but a bit salty
# Predicted summary:  not a good quality
#
#
# # 116
# Text: wallflower blooms duke succumbs duke finds masquerade lady identity country party waiting aubrey sisters story
# Original summary: a true romance of errors
# Predicted summary:  a quick read
#
#
# # 117
# Text: nutritious bought total 96 packets add breakfast bags homeless figure form quick energy tucked pocket consume later worries peanut allergies produced 100 peanut free facility tried make sure flavor right would never almond butter tastes somewhat similar peanut butter love bit milder might expect printed package instructions squeeze mix enjoy something effect problem ones tried would buy good 100 whole wheat sesame seed ak mak crackers also sold amazon com easily squirted packet onto crackers opened
# Original summary: excellent exactly as expected perfect taste consistency
# Predicted summary:  not a good product
#
#
# # 118
# Text: eat walking work save time get good burst carbs start day tasty feel good eating healthy
# Original summary: great way to start your morning
# Predicted summary:  great for low carb diets
#
#
# # 119
# Text: death waltz vienna great book full mystery intrigue romance keeps one edge right end rather different approach mystery author must done great deal research well travelled across europe guessing descriptions
# Original summary: great historical mystery
# Predicted summary:  a great mystery
#
#
# # 120
# Text: chose rating good book liked story good mystery within refer book friends
# Original summary: buried in benidorm
# Predicted summary:  a good read
#
#
# # 121
# Text: book beautiful inspiring author gave romance christian setting loved 2 thumbs
# Original summary: good christian read
# Predicted summary:  a beautiful love story
#
#
# # 122
# Text: cannot find french vanilla jell instant pudding grocery found online good price delighted use lot
# Original summary: great to find this item
# Predicted summary:  great vanilla pudding
#
#
# # 123
# Text: keys diary rarity among contemporary romance novels endearing funny sexy first person narrative inside look journaled life fern burns fern 25 year old damsel vapid distress hard hearted waiting 34 broken 34 man rather got personality spunk adds new life genre loved uncommon entertaining take romance reads easily keeps hooked events fern life seriously steamy moments cheesy overdone novel refreshing say least romance lovers writers take note
# Original summary: endearing funny and sexy
# Predicted summary:  a fun read
#
#
# # 124
# Text: chips fresh shipped safely way afghanistan quickly would definately order chips finish others
# Original summary: chip a hoy
# Predicted summary:  chips were a surprise
#
#
# # 125
# Text: written cookbooks used product recipes years believe best purpose seasoning market lulu grace
# Original summary: best seasoning on the market
# Predicted summary:  great recipes for cooking
#
#
# # 126
# Text: liked much ordered second unit chrome carousel counter use pantry extra storage would look good counter metal welded construction nice paint job also good neutral colored rubber feet leave marks counters shelves one thing see mentioned drawers come way great k cups end place great cleaning still think great especially consider price definitely would recommend
# Original summary: great k cup storage
# Predicted summary:  great coffee great price
#
#
# # 127
# Text: book one whole series grounded real history characters course made location time period 100 mark kind book really enjoy reading especially visually imagine characters situation maybe try write calling sleep suffice say excellent book well worth reading guaranteed love
# Original summary: excellent days it all
# Predicted summary:  a great read
#
#
# # 128
# Text: many teas taste good decaf versions earl grey hit buy regularly enjoy year long plus popular tea guests fall winter months br br say absolute favorite decaf tea
# Original summary: favorite decaf tea
# Predicted summary:  great tea great price
#
#
# # 129
# Text: ha ending phew unexpected book roller coaster ride pull preach hate love constant loved throughout lets face men screw loved preach first saw daisy maker absolutely amazing redeemed eyes cannot wait timbers story emily minton dawn martens knows mc know drama know shock unbelievably well surprised book talked hopefully lot come two far wrong hanging every word
# Original summary: this book is so incredibly worth it
# Predicted summary:  a must read
#
#
# # 130
# Text: coffee ok mild almost bordering weak would buy price right
# Original summary: just ok coffee
# Predicted summary:  not bad at all
#
#
# # 131
# Text: clear scalp hair beauty volumizing root boost nourishing conditioner works well pleasant overpowering scent use conditioner conjunction clear shampoo add volume hair br br conditioner hit three four family members son saying leaves long hair feeling slick everyone else liking enough keep using br br mostly recommended might try see right br br cfh
# Original summary: it is a good conditioner recommended
# Predicted summary:  it is ok
#
#
# # 132
# Text: purchasing boxed coconutwater seemed vbe discontnued order lrger plasticbollted water found taste diffeent know bttle changes taste fr box little disappointed zico
# Original summary: not as good as their box water
# Predicted summary:  not what i expected
#
#
# # 133
# Text: book lot twists turns one trusted sad happened family book curious find person awful things going download gangster daughter 2
# Original summary: a quick read
# Predicted summary:  a good read
#
#
# # 134
# Text: probably single best thing improve health live longer healthier life fitness nut believe 100 disease suffer modern world goes back diet gmos pesticides food poison saying 8220 let food thy medicine medicine thy food 8221 8213 hippocrates agree fullest best way start process eat organic better eat organic local book comes gives ability steps super informative must buy
# Original summary: let your food be your medicine
# Predicted summary:  great information for the health
#
#
# # 135
# Text: ok know time gotten around finally reading morgan parker books smh wondering took long make effort say officially fan mp little hesitant saw format book quickly forgot hangup sucked right away read one day hanging pool yup makes great pool beach wherever read really loved able connect characters pleasant surprise given initial hesitation looking crazy awesome unique read grab
# Original summary: i am a fan
# Predicted summary:  i was not disappointed
#
#
# # 136
# Text: found author already love books short worth want husband like
# Original summary: love this author
# Predicted summary:  short and sweet
#
#
# # 137
# Text: started low cal diet found tuna almost perfect food except tastes bit fishy started using iguana radioactive explosively hot atomic pepper sauce wow tuna ever perfect food open drain smother iguana eat stuff better tobasco
# Original summary: good with tuna
# Predicted summary:  not a bad taste
#
#
# # 138
# Text: cat loves scratcher stops scratching carpet furniture got scratcher scratcher works properly prepared toy really toy small paper ball br
# Original summary: very nice scratcher
# Predicted summary:  my cat loves these
#
#
# # 139
# Text: discovered tea couple years ago trip colorado liked much wrote name could buy luck initially recently searched course available amazon com every bit good remember tea fragrant flavorful truly good stuff also ordered african nectar amazing
# Original summary: love love love this tea
# Predicted summary:  best tea ever
#
#
# # 140
# Text: chivalry dead one favorites pennyfoot hotel series far excellent cliff hanger hardly wait read next book find happens next
# Original summary: chivalry is dead
# Predicted summary:  a great read
#
#
# # 141
# Text: sister first recommended book whilst holiday together daughter enjoyed naturally mine different sure know someone like main character mikka definitely relate finished whole thing two sittings real page turner would recommend anyone looking good read start 2014
# Original summary: a real page turner
# Predicted summary:  a great read
#
#
# # 142
# Text: beef jerky kick lately one new favorites starts tenderness meat meat soft side still nice chew real pieces apposed artificial looking variety flavor nice smoky bbq base sweetness honey mild heat chipolte perfect tried multiple sweet baby ray products yet disappointed grab bag two disappointed
# Original summary: a new favorite
# Predicted summary:  good but not great
#
#
# # 143
# Text: follower becket really ready read blood vivicanti disappointed mary paige felt alone life starts new school arts finally fitting becoming part crowd things change dramatically first series books biting nails see changes happen mary paige becket found genre love since first read anne rice interview vampire twist adds vampire great cannot wait dig deeper blood vivicanti see ride takes would recommend book people think anne rice name book read think anne clearly becket tone formatting much different hope becket continues genre right huge fan
# Original summary: awesome new take
# Predicted summary:  a new twist on vampire vampire
#
#
# # 144
# Text: wonderful little nuggets ginger taste plus another flavor mango peanut butter great settle stomach meal even help gastric reflux 2 pound bag flavors mixed meets needs 2 months
# Original summary: great product quickly shipped
# Predicted summary:  great ginger flavor
#
#
# # 145
# Text: first book series book needs editing fraught grammatical punctuation errors flabbergasted see used beaucoup really romance feels contrived main character frequently seems hormonal volatile pubescent manner would nice definition dentelle reiterated enjoy references location familiar author might want check online author groups google 34 author critique groups 34 input ms bowhay spins good yarn needs polishing
# Original summary: good story but needs editing
# Predicted summary:  good story but
#
#
# # 146
# Text: recommend book series started reading could put finished wanted read looking forward book 5 hard wait next book great author love books
# Original summary: i love this book and series
# Predicted summary:  great book for a series
#
#
# # 147
# Text: glad see amazon many products suppliers nice products delivered right house getting ready order 3 additional mouths feed house
# Original summary: as advertised great option vs retail stores
# Predicted summary:  very good product
#
#
# # 148
# ...
#
#
# # 760
# Text: familiar pg tips know england 1 tea reason pg tips cheapest tea england excellent product usa found better tea purchased bulk excellent used purchasing tea american grocery store pg tips certainly cost less weak american tea live wisconsin truly awful teas sell equivalent 10 cents bag pg tips high quality low priced favorite tea
# Original summary: the best tea for a great price
# Predicted summary:  good value for the price
#
#
# # 761
# Text: loved book great series suggest start book one keep reading fun read characters great hope enjoy book much fun reading
# Original summary: loved this book
# Predicted summary:  great book for a series
#
#
# # 762
# Text: enjoyed series good read mystery good enjoy homemade quality characters town enjoy books series keep going see happened
# Original summary: good summer read
# Predicted summary:  good book but
#
#
# # 763
# Text: first time tasted stash tea disappointed great price well packaged individual tea bags well general package tastes great
# Original summary: delicious tea great price
# Predicted summary:  great tea great price
#
#
# # 764
# Text: okay little garden back yard attracts lot flies looking way combat house sure still made fly paper saw searching great amazon excited moment opened box dismayed seriously cannot decide joke packaging says box stunning 3 images draw flies images perhaps funniest drawing ever seen called 3 product caught single fly simply ignore fly everywhere stunningly realistic 3 images anyone got better idea br br buy unless playing joke someone
# Original summary: is this a joke
# Predicted summary:  not as pictured
#
#
# # 765
# Text: connie suttle amazing continuing saga lissa company fun read vamp fans refreshing find sometimes stale genre new life mixed looking forward next installment
# Original summary: blood war blood destiny
# Predicted summary:  fun fun read
#
#
# # 766
# Text: calling bacon curls bit stretch fact tasty pork rinds fairly certain bacon bacon
# Original summary: not to shabby
# Predicted summary:  not bacon but good
#
#
# # 767
# Text: love coffee since cannot drink caffeine one coffee world wonderful full flavor prices gotten way hand draw back find trying coffees around world date none matched flavor illy caffe decaffeinated
# Original summary: illy caffe decaf whole bean coffee
# Predicted summary:  best coffee ever
#
#
# # 768
# Text: treats investigation fda issued several warnings 2000 complaints illness 300 deaths linked treats sales slowed manufacturers trying generate sales buy waggin train made china dog treats page admin remove offer br check br fda warning
# Original summary: potentially lethal under fda investigation
# Predicted summary:  made in china
#
#
# # 769
# Text: recieved one listed br emerald cocktail peanuts 12 ounce canisters pack 12 received one 4 0 bag diamond chopped pecans br br emerald sea salt pepper cashew 10oz canister pack 4 received one 4 0 bag diamond chopped walnuts br br deal cannot return ordered even close ordered br br please fix
# Original summary: do not believe this
# Predicted summary:  almonds with almonds
#
#
# # 770
# Text: used get way back hs 1981 1984 loved ever since internet came would look via search engines taste good recipe seems totally unchanged fake chewy kind cookies seem norm emulsifiers dry somewhat crumbly cookies hint maltiness chocolate chips slightly cool tongue melt mouth ordered put desk office keep ordering co workers give four stars cookie plus one star changing recipe
# Original summary: thankfully still the same
# Predicted summary:  not what i expected
#
#
# # 771
# Text: really love seaweed snacks although every one else given try disliked think real love hate sort item br br like seaweed sushi would probably like strips like dry paper thin strips quite salty little bit spice first crispy become soft chewed usually eat two packets 8 strips total time br br think price high sure buy right eating every day great little snack love
# Original summary: love it or hate it
# Predicted summary:  healthy snack for a snack
#
#
# # 772
# Text: say movie falisa boss every sense word way moves accuracy grace queen way labeled princess gunning crown good way princess amil needs beheaded asap
# Original summary: watch the throne
# Predicted summary:  a good read
#
#
# # 773
# Text: sometimes want goldfish crackers want cheat diet good moments really really salty fulfills craving tastes like baked cheese exactly
# Original summary: perfect for low carb dieting super salty
# Predicted summary:  not a fan
#
#
# # 774
# Text: nice little story attraction turn love lead female character strong self assured woman nice read pool beach
# Original summary: good story short read
# Predicted summary:  a nice story
#
#
# # 775
# Text: omg totally disagree 2 star giver made last night know gluten free would never would guessed would thought multi grain wheat penne best great nice firm texture great flavor grains good think found favorite mushy rice corn pasta anymore
# Original summary: best tasting gluten free penne
# Predicted summary:  gluten free pasta
#
#
# # 776
# Text: learned great deal book new greenhouse type gardening found lots useful information helpful tips book book good novice experienced gardeners go resource
# Original summary: love greenhouse gardening
# Predicted summary:  great book for beginners
#
#
# # 777
# Text: sister suggested tea looking good herbal tea limit caffeine one could evening herbal teas seem weak big licorice fan taste strongly licorice one reviewers said gives slightly sweet slightly licorice aftertaste delightful great evening craving something sweet calories caffeine
# Original summary: the absolute best herbal tea
# Predicted summary:  a great treat
#
#
# # 778
# Text: eaten kind bar definitely flavor realize opened tasted love mango love macadamia bar together great bad cup tea mango little artificial get macadamia crunch would say try another flavor
# Original summary: not my kind of flavor
# Predicted summary:  not what i expected
#
#
# # 779
# Text: friend suggested read even though never read series based found story compelling interesting guess need back track read rest series also hoping part story good read never put time started reading
# Original summary: eager to read more of the story
# Predicted summary:  a good read
#
#
# # 780
# Text: great baking business use vegan double chocolate chip muffins price great time update review 8 3 10 return purchased 8 3 2010 price jump 38 79 pack 12 119 95 pack 12 like chips pay less health food stores like chips check around find cheaper 119 95 pack 12 href http www amazon com gp product let organic shredded unsweetened coconut 8 ounce packages pack 12 href http www amazon com gp product farmer market foods organic canned pumpkin pie mix 15 ounce cans pack 12
# Original summary: my lady muffins
# Predicted summary:  great price for a great product
#
#
# # 781
# Text: received arc honest review book 2 3 book series let tell heart throat tears eyes powerful full raw emotion sadness anger happiness love angst friendships highly recommend book series nicola writes passion 34 gusto 34 fact writes constantly even birthday wish author happiness success achieve writing started series waiting grab books 34 hold tight 34 happy reading favorite book vixen 60 3
# Original summary: wow just wow
# Predicted summary:  a must read
#
#
# # 782
# Text: taste like cough syrup kind sugary plastic unnatural taste slightly bittersweet taste br br wait exactly sweet slightly bitter leaves strange chemical like unnatural sensation tongue yup taste like cough syrup
# Original summary: taste like cough syrup
# Predicted summary:  not bad but not bad either
#
#
# # 783
# Text: due studies yoga ayurveda would heard benefits black salt glad decided try made wonderful interesting addition food preparation would recommend anyone buying read first unusual odor flavor much like hard boiled eggs volcanic contains lot sulphur fact like himalayan salt use finishing salt cook like himalayan salt understand black salt hold water said raise sodium content body finely ground little goes long way comes really neat little glass jar would definitely purchase
# Original summary: black salt is phenomenal
# Predicted summary:  a great book for all
#
#
# # 784
# Text: usually pan fry pork always comes little dry flavor lacking tried cover pork seasonings put oven hardly work cleanup pork nice moist flavorful great product
# Original summary: makes pork tender and delectable
# Predicted summary:  good but not great
#
#
# # 785
# Text: series amazing found many times sitting pondering different situations actually wondering next read book found emotional rollercoaster starting page one final word final page even laughed time two fifth book series read many books series genre honestly say series best saddened whole year book six comes positive worth wait already definitely read series read
# Original summary: gets better and better
# Predicted summary:  i love this series
#
#
# # 786
# Text: cute story use teaching changing seasons 8 year old enjoyed illustrations great
# Original summary: love the illustrations
# Predicted summary:  cute story for kids
#
#
# # 787
# Text: well written short comedy story kept laughing loud couldnt put sort book
# Original summary: a good comedy
# Predicted summary:  funny and funny
#
#
# # 788
# Text: good read ghost want anybody coming town take nothing want share piece pie send 3 deadliest goons take anybody taking away business flex new guy taking cheap prices even taking one goons girl never get caught slipping town full killer
# Original summary: ghost where you at
# Predicted summary:  a good ghost story
#
#
# # 789
# Text: story really makes think really important something known long time family best gift
# Original summary: makes you think
# Predicted summary:  a good story
#
#
# # 790
# Text: go looking much depth love first sight jump bed type book somehow separated 3 years love first sight back bed want trite romance
# Original summary: fine but shallow
# Predicted summary:  i am hooked on this author
#
#
# # 791
# Text: liked story know expect truly care told would taken short journey going spoil anything read last couple pages times figure got right
# Original summary: revenge does not always work out
# Predicted summary:  a good story
#
#
# # 792
# Text: noire waiting see chair real man surprised book crazzzzy loved juicy went one bad thing next man girl get break said even 20 yet much cant wait see happen salida definately nooni smh cant help want say see hot ass starting book 5 series good glad waited till start reading good job noire
# Original summary: envy the 4th deadly sin
# Predicted summary:  i am hooked on this series
#
#
# # 793
# Text: wow expect little gem give book chance well written felt characters immediately look author see next comes loved
# Original summary: what an awesome surprise
# Predicted summary:  a great read
#
#
# # 794
# Text: brownie mix came us gift box loved bought case since problems supposed oily come bubbly liquidy remember first time like separate baked edges goo middle matter long baked still eat wonder something wrong something wrong
# Original summary: what am i doing wrong
# Predicted summary:  not as good as the others
#
#
# # 795
# Text: buy amazon bought use cake pops tastes better colored candy melts sell stores hardens better candy melts hard melt stay chunky clumpy making necessary add shortening shortening makes harder candy quickly dry harden also difficult use edible markers candy melts shortening makes oily br almond bark melts silky smooth consistency write perfectly edible markers also candy dries nice crunchy candy shell way
# Original summary: smells and tastes delicious
# Predicted summary:  a good candy
#
#
# # 796
# Text: one people need much reminders details getting debts book perfect author really knew explains debts affect people many ways find book helpful great reminder never right let debts affect take life book worth getting reading
# Original summary: helpful and informative
# Predicted summary:  a great book for everyone
#
#
# # 797
# Text: ally stitches would accidentally book cruise friend wrong theme first thought go bunch seniors young lady ally surprised jj kane perfect dynamics made sense kane hiding cruise boat nursing injury avoiding publicity girl deal mishap girlfriend couple favorite scenes jj finds next door neighbors keep night older couple hanging bets placing jj kane even though could cost kane job
# Original summary: young lady 2nd honeymoon cruise
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-0619872ff2bb> in <module>()
#       3   print("Text:",text(text_val[i]))
#       4   print("Original summary:",summary(summary_val[i]))
# ----> 5   print("Predicted summary:",predicted(text_val[i].reshape(1,maximum_text_length)))
#       6   print("\n")
#
# <ipython-input-24-1ae6465c9eb9> in predicted(input_seq)
#      13     while not quitt:
#      14
# ---> 15         output_tokens, h, c = decoder_model.predict([sequence] + [e_out, e_h, e_c])
#      16
#      17         # Sample a token
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      86       raise ValueError('{} is not supported in multi-worker mode.'.format(
#      87           method.__name__))
# ---> 88     return method(self, *args, **kwargs)
#      89
#      90   return tf_decorator.make_decorator(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1247           workers=workers,
#    1248           use_multiprocessing=use_multiprocessing,
# -> 1249           model=self)
#    1250
#    1251       # Container that configures and calls `tf.keras.Callback`s.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model)
#    1110         use_multiprocessing=use_multiprocessing,
#    1111         distribution_strategy=ds_context.get_strategy(),
# -> 1112         model=model)
#    1113
#    1114     strategy = ds_context.get_strategy()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     326     # trigger the next permutation. On the other hand, too many simultaneous
#     327     # shuffles can contend on a hardware level and degrade all performance.
# --> 328     indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     329
#     330     def slice_batch_indices(indices):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic)
#    1619     """
#    1620     if num_parallel_calls is None:
# -> 1621       return MapDataset(self, map_func, preserve_cardinality=True)
#    1622     else:
#    1623       return ParallelMapDataset(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function)
#    3986         use_inter_op_parallelism=self._use_inter_op_parallelism,
#    3987         preserve_cardinality=self._preserve_cardinality,
# -> 3988         **self._flat_structure)
#    3989     super(MapDataset, self).__init__(input_dataset, variant_tensor)
#    3990
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, use_inter_op_parallelism, preserve_cardinality, name)
#    2799         "output_types", output_types, "output_shapes", output_shapes,
#    2800         "use_inter_op_parallelism", use_inter_op_parallelism,
# -> 2801         "preserve_cardinality", preserve_cardinality)
#    2802       return _result
#    2803     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
# text = this is such a disgusting tea, I hate it so much argh,, so very very bad
text = input("Text: ")

clean = content_cleaner(text)

accepted = []
accepted.append(clean)

accepted = list(map(lambda x: 'starttoken '+ x + ' endtoken', accepted))

#convert text sequences into integer sequences
accepted = x_tokenizer.texts_to_sequences(accepted)

#ensures all sequences in the list have the same length
accepted = pad_sequences(accepted, maxlen = maximum_text_length, padding='post')

print("Predicted: ",predicted(accepted[0].reshape(1,maximum_text_length)))
# Out:
# Text: this is such a disgusting tea, I hate it so much argh,, so very very bad
# Predicted:   not what i expected
