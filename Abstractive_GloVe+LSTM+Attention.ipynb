# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
import pandas as pd
import numpy as np
import re
import string
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from keras import backend as K
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K
from nltk.corpus import stopwords  
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer 
from keras.preprocessing.sequence import pad_sequences
import nltk
nltk.download('stopwords')
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Read the Data
data1 = pd.read_csv('Reviews.csv')
print(data1.columns)
#remove uneccessary columns 
data1 = data1.drop(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
       'HelpfulnessDenominator', 'Score', 'Time'], axis = 1)
print("Removed unecessary columns")
print(data1.head())
for i in range(5):
  print(data1.Text[i])
  print(data1.Summary[i])
  print('\n')
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')
# Removed unecessary columns
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...
# I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.
# Good Quality Dog Food
#
#
# Product arrived labeled as Jumbo Salted Peanuts...the peanuts were actually small sized unsalted. Not sure if this was an error or if the vendor intended to represent the product as "Jumbo".
# Not as Advertised
#
#
# This is a confection that has been around a few centuries.  It is a light, pillowy citrus gelatin with nuts - in this case Filberts. And it is cut into tiny squares and then liberally coated with powdered sugar.  And it is a tiny mouthful of heaven.  Not too chewy, and very flavorful.  I highly recommend this yummy treat.  If you are familiar with the story of C.S. Lewis' "The Lion, The Witch, and The Wardrobe" - this is the treat that seduces Edmund into selling out his Brother and Sisters to the Witch.
# "Delight" says it all
#
#
# If you are looking for the secret ingredient in Robitussin I believe I have found it.  I got this in addition to the Root Beer Extract I ordered (which was good) and made some cherry soda.  The flavor is very medicinal.
# Cough Medicine
#
#
# Great taffy at a great price.  There was a wide assortment of yummy taffy.  Delivery was very quick.  If your a taffy lover, this is a deal.
# Great taffy

# %%
# Read the Data
data2 = pd.read_csv('kindle_reviews.csv')
print(data2.columns)
#remove uneccessary columns 
data2 = data2.drop(['Unnamed: 0', 'asin', 'helpful', 'overall','reviewTime', 
        'reviewerID', 'reviewerName','unixReviewTime'], axis = 1)
print("Removed unecessary columns")
data2.rename(index = str, columns = {'summary':'Summary', 'reviewText':'Text'}, inplace = True)
data2 = data2[['Summary','Text']]
# print(data2.head())
for i in range(5):
  print(data2.Text[i])
  print(data2.Summary[i])
  print('\n')
# Out:
# Index(['Unnamed: 0', 'asin', 'helpful', 'overall', 'reviewText', 'reviewTime',
#        'reviewerID', 'reviewerName', 'summary', 'unixReviewTime'],
#       dtype='object')
# Removed unecessary columns
# I enjoy vintage books and movies so I enjoyed reading this book.  The plot was unusual.  Don't think killing someone in self-defense but leaving the scene and the body without notifying the police or hitting someone in the jaw to knock them out would wash today.Still it was a good read for me.
# Nice vintage story
#
#
# This book is a reissue of an old one; the author was born in 1910. It's of the era of, say, Nero Wolfe. The introduction was quite interesting, explaining who the author was and why he's been forgotten; I'd never heard of him.The language is a little dated at times, like calling a gun a &#34;heater.&#34;  I also made good use of my Fire's dictionary to look up words like &#34;deshabille&#34; and &#34;Canarsie.&#34; Still, it was well worth a look-see.
# Different...
#
#
# This was a fairly interesting read.  It had old- style terminology.I was glad to get  to read a story that doesn't have coarse, crasslanguage.  I read for fun and relaxation......I like the free ebooksbecause I can check out a writer and decide if they are intriguing,innovative, and have enough of the command of Englishthat they can convey the story without crude language.
# Oldie
#
#
# I'd never read any of the Amy Brewster mysteries until this one..  So I am really hooked on them now.
# I really liked it.
#
#
# If you like period pieces - clothing, lingo, you will enjoy this mystery.  Author had me guessing at least 2/3 of the way through.
# Period Mystery

# %%
data = pd.concat([data2, data1])
print(data.head())
# Out:
#               Summary                                               Text
# 0  Nice vintage story  I enjoy vintage books and movies so I enjoyed ...
# 1        Different...  This book is a reissue of an old one; the auth...
# 2               Oldie  This was a fairly interesting read.  It had ol...
# 3  I really liked it.  I'd never read any of the Amy Brewster mysteri...
# 4      Period Mystery  If you like period pieces - clothing, lingo, y...

# %%
#checking for any empty data
print("Checking for empty data: ")
print(data.isnull().sum())
print('\n')
#remove any empty data 
data = data.dropna()
data = data.reset_index(drop = True)

#checking if the empty data has been deleted
print("Checking again for empty data: ")
print(data.isnull().sum())

print(data.head())
# Out:
# Checking for empty data:
# Summary    28
# Text       22
# dtype: int64
#
#
# Checking again for empty data:
# Summary    0
# Text       0
# dtype: int64
#               Summary                                               Text
# 0  Nice vintage story  I enjoy vintage books and movies so I enjoyed ...
# 1        Different...  This book is a reissue of an old one; the auth...
# 2               Oldie  This was a fairly interesting read.  It had ol...
# 3  I really liked it.  I'd never read any of the Amy Brewster mysteri...
# 4      Period Mystery  If you like period pieces - clothing, lingo, y...

# %%
#expand common contractions inside the text
contraction_expander = { 
"ain't": "am not", "aren't": "are not", "can't": "cannot", "can't've": "cannot have", "'cause": "because", "could've": "could have", "couldn't": "could not",
"couldn't've": "could not have", "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hadn't've": "had not have", "hasn't": "has not",
"haven't": "have not", "he'd": "he would", "he'd've": "he would have","he'll": "he will", "he's": "he is", "how'd": "how did", "how'll": "how will","how's": "how is",
"i'd": "i would","i'll": "i will","i'm": "i am","i've": "i have", "isn't": "is not","it'd": "it would","it'll": "it will","it's": "it is","let's": "let us","ma'am": "madam",
"mayn't": "may not","might've": "might have","mightn't": "might not","must've": "must have","mustn't": "must not","needn't": "need not","oughtn't": "ought not","shan't": "shall not",
"sha'n't": "shall not","she'd": "she would", "she'll": "she will","she's": "she is","should've": "should have","shouldn't": "should not","that'd": "that would", "that's": "that is",
"there'd": "there had","there's": "there is","they'd": "they would","they'll": "they will", "they're": "they are","they've": "they have","wasn't": "was not","we'd": "we would",
"we'll": "we will","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what're": "what are","what's": "what is", "what've": "what have",
"where'd": "where did","where's": "where is","who'll": "who will","who's": "who is", "won't": "will not","wouldn't": "would not","you'd": "you would","you'll": "you will",
"you're": "you are"
}

# %%
#function to clean the text and summary
stop_words = set(stopwords.words('english')) 
def content_cleaner(content, remove_stop_words=True):
    text = content.lower()

    #expand the contractions
    expanded_form = []
    for i in text.split():
      if i in contraction_expander:
        expanded_form = expanded_form + [contraction_expander[i]]
      else:
        expanded_form = expanded_form + [i]
    text = ' '.join(expanded_form)

    #remove the punctuations
    regex = re.compile('[%s]' % re.escape(string.punctuation))         
    text = regex.sub(" ", text)
    
    #whitespace
    text = re.sub('\s+', ' ', text).strip()  

    #stopwords removal
    if remove_stop_words:
        remove = [i for i in text.split() if not i in stop_words]  
        text = (" ".join(remove)).strip()

    return text

#clean the text and append into an array
clean_texts = []
for text in data.Text:
    clean_texts.append(content_cleaner(text,remove_stop_words=True))
print("Text Appended.")

#clean the summary and append into an array
clean_summaries = []
for summary in data.Summary:
    clean_summaries.append(content_cleaner(summary,remove_stop_words=False))
print("Summaries Appended.")

#checking 
for i in range(3):
  print("Text:\n", clean_texts[i])
  print("Summary:\n", clean_summaries[i])
# Out:
# Text Appended.
# Summaries Appended.
# Text:
#  enjoy vintage books movies enjoyed reading book plot unusual think killing someone self defense leaving scene body without notifying police hitting someone jaw knock would wash today still good read
# Summary:
#  nice vintage story
# Text:
#  book reissue old one author born 1910 era say nero wolfe introduction quite interesting explaining author forgotten would never heard language little dated times like calling gun 34 heater 34 also made good use fire dictionary look words like 34 deshabille 34 34 canarsie 34 still well worth look see
# Summary:
#  different
# Text:
#  fairly interesting read old style terminology glad get read story coarse crasslanguage read fun relaxation like free ebooksbecause check writer decide intriguing innovative enough command englishthat convey story without crude language
# Summary:
#  oldie

# %%
#see the distirbution
def distribution_length(text):
    lengths = []
    for sentence in text:
        lengths.append(len(sentence))
    return pd.DataFrame(lengths, columns=['counts'])

lengths_summaries = distribution_length(clean_summaries)
lengths_texts = distribution_length(clean_texts)

print("Describe Summaries:")
print(lengths_summaries.describe())
print('\n')
print("Describe Texts:")
print(lengths_texts.describe())
# Out:
# Describe Summaries:
#              counts
# count  1.551023e+06
# mean   2.211637e+01
# std    1.479597e+01
# min    0.000000e+00
# 25%    1.200000e+01
# 50%    1.800000e+01
# 75%    2.900000e+01
# max    2.490000e+02
#
#
# Describe Texts:
#              counts
# count  1.551023e+06
# mean   3.314817e+02
# std    3.977787e+02
# min    0.000000e+00
# 25%    1.080000e+02
# 50%    1.930000e+02
# 75%    3.830000e+02
# max    1.490900e+04

# %%
#checking lengths
count_text = 0
for i in clean_texts:
    if(len(i.split()) >= 10):
        count_text = count_text + 1
print("Minimum Text: ")
print(count_text/len(clean_texts))

count_summary = 0
for i in clean_summaries:
    if(len(i.split()) >= 5):
        count_summary = count_summary + 1
print("Minimum Summary: ")
print(count_summary/len(clean_summaries))
            
count_text = 0
for i in clean_texts:
    if(len(i.split()) <= 100):
        count_text = count_text + 1
print("Maximum Text: ")
print(count_text/len(clean_texts))

count_summary = 0
for i in clean_summaries:
    if(len(i.split()) <= 8):
        count_summary = count_summary + 1
print("Maximum Summary: ")
print(count_summary/len(clean_summaries))
# Out:
# Minimum Text:
# 0.9702377076290938
# Minimum Summary:
# 0.3366887531648467
# Maximum Text:
# 0.8796916615678814
# Maximum Summary:
# 0.9253931115141426

# %%
#place limitations on data due to computational limitations
minimum_text_length = 10
maximum_text_length = 100
minimum_summary_length = 3
maximum_summary_length = 8

#arrays to store summaries & texts that fit the requirements
accepted_summaries = []
accepted_texts = []

for i in range(len(clean_texts)):
  if(len(clean_summaries[i].split())>=minimum_summary_length and len(clean_summaries[i].split())<=maximum_summary_length and
        len(clean_texts[i].split()) >=minimum_text_length and len(clean_texts[i].split())<=maximum_text_length ):
    accepted_summaries.append(clean_summaries[i])
    accepted_texts.append(clean_texts[i])

#length of summaries and text
print("Summaries:", len(accepted_summaries))
print("Text:", len(accepted_texts))
# Out:
# Summaries: 770612
# Text: 770612

# %%
#see the distirbution of the accepted text and summaries
lengths_accepted_summaries = distribution_length(accepted_summaries)
lengths_accepted_texts = distribution_length(accepted_texts)

print("Describe Summaries:")
print(lengths_accepted_summaries.describe())
print('\n')
print("Describe Texts:")
print(lengths_accepted_texts.describe())
# Out:
# Describe Summaries:
#               counts
# count  770612.000000
# mean       24.158857
# std         8.893600
# min         5.000000
# 25%        17.000000
# 50%        23.000000
# 75%        30.000000
# max        77.000000
#
#
# Describe Texts:
#               counts
# count  770612.000000
# mean      238.107431
# std       149.711506
# min        27.000000
# 25%       118.000000
# 50%       194.000000
# 75%       323.000000
# max       830.000000

# %%
# Add tokens at the begining and the end of the summaries
accepted_summaries = list(map(lambda x: 'starttoken '+ x + ' endtoken', accepted_summaries))

# %%
text_train,text_val,summary_train, summary_val = train_test_split(np.array(accepted_texts),np.array(accepted_summaries), test_size = 0.2, random_state=0)
#tokenizer for text 
x_tokenizer = Tokenizer()
x_tokenizer.fit_on_texts(list(text_train))

count = 0
for i in x_tokenizer.word_counts.items():
  count = count + 1

#tokenizer for text 
x_tokenizer = Tokenizer(num_words = count)
x_tokenizer.fit_on_texts(list(text_train))

#convert text sequences into integer sequences
text_train = x_tokenizer.texts_to_sequences(text_train)
text_val = x_tokenizer.texts_to_sequences(text_val)

#ensures all sequences in the list have the same length
text_train = pad_sequences(text_train, maxlen = maximum_text_length, padding='post')
text_val = pad_sequences(text_val, maxlen = maximum_text_length, padding='post')

x_vocab = x_tokenizer.num_words + 1

# #tokenizer for summary
y_tokenizer = Tokenizer()
y_tokenizer.fit_on_texts(list(summary_train))

count = 0
for i in y_tokenizer.word_counts.items():
  count = count + 1

y_tokenizer = Tokenizer(num_words = count)
y_tokenizer.fit_on_texts(list(summary_train))

#convert text sequences into integer sequences
summary_train = y_tokenizer.texts_to_sequences(summary_train)
summary_val = y_tokenizer.texts_to_sequences(summary_val)

#padding zero upto maximum length
summary_train = pad_sequences(summary_train, maxlen = maximum_summary_length, padding='post')
summary_val = pad_sequences(summary_val, maxlen = maximum_summary_length, padding='post')

y_vocab = y_tokenizer.num_words + 1

# %%
#check if there are summaries that only contains the tokens in training data
temp = []
for i in range(len(summary_train)):
    count = 0 
    for j in summary_train[i]:
        if j != 0:
            count = count + 1
    if(count == 2):
        temp.append(i)

#delete 
summary_train=np.delete(summary_train,temp, axis=0)
text_train=np.delete(text_train,temp, axis=0)

#check if there are summaries that only contains the tokens in test data
temp2 = []
for i in range(len(summary_val)):
    count=0
    for j in summary_val[i]:
        if j!= 0:
            count = count + 1
    if(count == 2):
        temp2.append(i)

#delete
summary_train=np.delete(summary_train,temp2, axis=0)
text_train=np.delete(text_train,temp2, axis=0)

# %%
#read glove word embeddings
embeddings_index = {}
f = open('glove.6B.100d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

word_index = x_tokenizer.word_index
embedding_matrix = np.zeros((len(word_index) + 1, 100))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
#taken from third party attention layer
class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
    """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                  shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                  initializer='uniform',
                                  trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                  shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                  initializer='uniform',
                                  trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                  shape=tf.TensorShape((input_shape[0][2], 1)),
                                  initializer='uniform',
                                  trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]

#model building
K.clear_session()
latent_dim = 500

#Encoder 
encoder_inputs = Input(shape = (maximum_text_length,))

#embedding layer
encoder_embedding = Embedding(x_vocab, 100, weights=[embedding_matrix],input_length=maximum_text_length, trainable=False)(encoder_inputs) 

#LSTM 1
encoder_lstm1 = LSTM(latent_dim, return_sequences=True, return_state=True)
encoder_output1, state_h1, state_c1 = encoder = encoder_lstm1(encoder_embedding)

#LSTM 2
encoder_lstm2 = LSTM(latent_dim, return_sequences=True, return_state=True,recurrent_dropout=0.3)
encoder_output2, state_h2, state_c2 = encoder = encoder_lstm2(encoder_output1)

#LSTM 3
encoder_lstm3 = LSTM(latent_dim, return_sequences=True, return_state=True)
encoder_outputs, state_h, state_c = encoder = encoder_lstm3(encoder_output2)

#Set up decoder
decoder_inputs = Input(shape=(None,))

#embedding layer
decoder_embedding_layer = Embedding(y_vocab, latent_dim, trainable = True)
decoder_embedding = decoder_embedding_layer(decoder_inputs)

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences = True, return_state = True)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(decoder_embedding, initial_state = [state_h, state_c])

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

#Concat attention output and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs,attn_out])

#Dense Layer
decoder_dense = TimeDistributed(Dense(y_vocab, activation='softmax')) 
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 100, 100)     16325900    input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 100, 500), ( 1202000     embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 100, 500), ( 2002000     lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 500)    23504000    input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 100, 500), ( 2002000     lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 500),  2002000     embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 500),  500500      lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 1000)   0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 47008)  47055008    concat_layer[0][0]
# ==================================================================================================
# Total params: 94,593,408
# Trainable params: 78,267,508
# Non-trainable params: 16,325,900
# __________________________________________________________________________________________________

# %%
#compile and run model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

history=model.fit([text_train,summary_train[:,:-1]], summary_train.reshape((summary_train.shape[0],summary_train.shape[1], 1))[:,1:] ,epochs=3,callbacks=[early_stopping],batch_size=512, validation_data=([text_val,summary_val[:,:-1]], summary_val.reshape(summary_val.shape[0],summary_val.shape[1], 1)[:,1:]))
# Out:
# Epoch 1/3
# 1205/1205 [==============================] - 1057s 877ms/step - loss: 3.6303 - val_loss: 3.1523
# Epoch 2/3
# 1205/1205 [==============================] - 1058s 878ms/step - loss: 2.9853 - val_loss: 2.9026
# Epoch 3/3
# 1205/1205 [==============================] - 1058s 878ms/step - loss: 2.7786 - val_loss: 2.7768

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# dictionary to convert the index to word 
reverse_summary_word_index=y_tokenizer.index_word
reverse_text_word_index=x_tokenizer.index_word
summary_word_index=y_tokenizer.word_index

# %%
#Inference
#Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

#Decoder 
#hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(maximum_text_length,latent_dim))

#embeddings of the decoder sequence
decoder_embedding2= decoder_embedding_layer(decoder_inputs) 
#setting initial states to the states from the previous time step for predicting next word
decoder_outputs2, state_h2, state_c2 = decoder_lstm(decoder_embedding2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense final output layer (softmax)
# generate prob distribution over the summary vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c], [decoder_outputs2] + [state_h2, state_c2])

# %%
def predicted(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    sequence = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    sequence[0, 0] = summary_word_index['starttoken']

    quitt = False
    predicted_summary = ''
    while not quitt:
      
        output_tokens, h, c = decoder_model.predict([sequence] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_summary_word_index[sampled_token_index]
        
        if(sampled_token!='endtoken'):
            predicted_summary += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'endtoken'  or len(predicted_summary.split()) >= (maximum_summary_length-1)):
            quitt = True

        # Update the target sequence (of length 1).
        sequence = np.zeros((1,1))
        sequence[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return predicted_summary

# %%
def summary(summary):
    original_sum = ''
    for i in summary:
        if((i!= 0 and i!= summary_word_index['starttoken']) and i!= summary_word_index['endtoken']):
            original_sum = original_sum + reverse_summary_word_index[i]+' '
    return original_sum

def text(text):
    original_text = ''
    for i in text:
        if(i!=0):
            original_text = original_text + reverse_text_word_index[i]+' '
    return original_text

for i in range(15):
  print("#",i+1)
  print("Text:",text(text_val[i]))
  print("Original summary:",summary(summary_val[i]))
  print("Predicted summary:",predicted(text_val[i].reshape(1,maximum_text_length)))
  print("\n")
# Out:
# # 1
# Text: delicious cookies cancelled subscription hope price comes back buy best ginger snaps found far price much
# Original summary: whoa that is quite a price increase
# Predicted summary:  ginger snaps at its best
#
#
# # 2
# Text: price would say green tea tastes superb usually drink green tea honey sweeteners tea perfect tastes great would recommend anyone likes green tea wants relatively cheap box set
# Original summary: great tasting green tea
# Predicted summary:  great tasting green tea
#
#
# # 3
# Text: think best gluten free cookies tried pamela mini cookies also good recipe back cookie crust desserts tried ginger snap crust little much ginger delicate tasting filling next time try using less crumbs sprinkle little topping tried chocolate cookies dessert crust yet ate 6 bag case fast
# Original summary: extremely good cookies
# Predicted summary:  best gluten free cookies
#
#
# # 4
# Text: book hard put enjoyed relationship h h friends family would want ryan good looking fighter pilot southern charm cass girl next door pretty smart may even sex scenes hot yet fun dressing role play looking forward books author
# Original summary: wow an officer and a gentleman 2013
# Predicted summary:  a great read
#
#
# # 5
# Text: devil contract hot like 34 holy crap claire knew could write sexy like hot 34 also mysterious filled suspense kept guessing wondering every twist turn 34 wonder 34 34 34 going head loved every minute love way claire writing always keeps toes
# Original summary: claire is a must read
# Predicted summary:  hot hot hot
#
#
# # 6
# Text: hoping precise suggestions says could could helpful suggesting add wall shelving removable stackable drawers papers call helpful organization solutions thought would include filing system instead telling make one kindle fire version
# Original summary: hoped for more
# Predicted summary:  good basic information
#
#
# # 7
# Text: book exciting thought going heroine book stubborn dramatic almost made want stop reading every predicament got continued reading loved hero brant alhough book predicatable begining could help drawn wonder men like fall love women like happens reality happen book like way book ended needed epilogue type follow brant home money going live going eat could sunshine rainbows left cave want light read something requires complexity great book read
# Original summary: not as exciting as i thought
# Predicted summary:  a great read
#
#
# # 8
# Text: came across short story first anthology story sure spooky enjoyed chills much read novel accompanies short story loved
# Original summary: haunting excellent read
# Predicted summary:  short but good
#
#
# # 9
# Text: series written 100 years ago interesting read tom swift language somewhat stilted actions interesting something think day age fun casual reading
# Original summary: books of the early 1900s
# Predicted summary:  a fun read
#
#
# # 10
# Text: really enjoyed books really kept going want put really knows make mad bad guy fall love good guys would recommend anyone likes love stories read two books
# Original summary: fate interrupted 1 2
# Predicted summary:  i loved it
#
#
# # 11
# Text: first new fan passed amazon recommendations years would read work wanted classic happily ever afters well decided read afterwards baby hooked characters flippin real smell sweat feel tears shake many climaxes book continuation mistress characters keisha jay ever evolving prevailed adversities challenged better nobody super rich beautiful yet flawed frail people want better true love story ms forrester wonderfully talented author makes true love seem like reality instead usual fantasy bravo cannot wait wife released
# Original summary: an excellent read
# Predicted summary:  a great read
#
#
# # 12
# Text: enjoyed riley chelle say one little drawn problem books major conflict riley reasons wanting manufactured would man spent 12 years marine recon guy really think still bad guy stupid teen honestly think brother still overbearing prick almost 30 little ridiculous would assume like bi polar mother never exhibited symptoms however relationship b w riley chelle sweet hot really like roll give douche fiance drops bombshell katie wedding strong heroine riley great except stupid reasons thinking good enough know sounds like like much jason katie could internal monologues shortened cut much better going keep going series
# Original summary: another good one
# Predicted summary:  a great read
#
#
# # 13
# Text: generally like cereal little less sugar add sweetener want otherwise good flake type cereal good quantity fiber little low protein compared cereal people generally add protein using milk add choice fruit usually like combination sliced banana strawberries sometimes add blueberries
# Original summary: one of the better high fiber cereals
# Predicted summary:  great cereal for a healthy cereal
#
#
# # 14
# Text: awesome romantic series set small town really get know everyone town cross paths lots love sad times naughty ones 128521
# Original summary: check it out
# Predicted summary:  love this series
#
#
# # 15
# Text: love case good quality great price good colors choose would highly recommend product
# Original summary: kindle fire case
# Predicted summary:  great product great price

# %%
for i in range(1000):
  print("#",i+1)
  print("Text:",text(text_val[i]))
  print("Original summary:",summary(summary_val[i]))
  print("Predicted summary:",predicted(text_val[i].reshape(1,maximum_text_length)))
  print("\n")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# # 168
# Text: read lot kids great went town instead lugging books around none books really held attention enjoy illustrations though
# Original summary: my kids were not very interested
# Predicted summary:  great for kids
#
#
# # 169
# Text: dog mini schnauzer often intestinal problems food really helped balance stomach problems helps know good
# Original summary: best food out there
# Predicted summary:  great dog food
#
#
# # 170
# Text: katie hornor paradise praises written devotional busy moms yearning meaningful time god feel guilty busy life keeps quiet time check devotional putting spirit one month study fruits spirit time moms take super hero capes cover spirit every day highly recommend devotion looking short study offers long lasting effect daily life
# Original summary: a must have devotion for busy moms
# Predicted summary:  a great book for all ages
#
#
# # 171
# Text: enjoyed three books would like see books author monster intrigue
# Original summary: the shadows edge
# Predicted summary:  a good read
#
#
# # 172
# Text: coffee ability make sometimes irritable edge br dandy blend pure flavor completely satisfying coffee lover gives healthy energy boost br grounds stir right hot water instant cup never leave anything behind bottom br look forward drinking dandy blend every morning
# Original summary: amazing i highly reccomend it
# Predicted summary:  great coffee for the price
#
#
# # 173
# Text: received arc book honest review great book laughed cried throughout reading mia adrian makes really believe 2nd chances routing awesome read lacey silks cannot wait read work
# Original summary: love deserves a 2nd chance
# Predicted summary:  i loved this book
#
#
# # 174
# Text: read first page know get book read book bought sound like gooding good book got little bit think going thought hate writers movies make sound good buy turns thought
# Original summary: do not know about this book
# Predicted summary:  not what i expected
#
#
# # 175
# Text: story van convicted robbery gone wrong tessa daughter man killed robbery setting pace tension two characters everything nicely done wonderful read definitely watching writer
# Original summary: fast paced read
# Predicted summary:  a great read
#
#
# # 176
# Text: mango chips quite yummy much healthier alternative potato chips plus taste great br br pros br small bags get stale br added sugar preservatives artificial flavors colors br crunchy without overly hard br full flavor br br cons br organic br expensive br makes fingers sticky br br great willing spend money
# Original summary: healthy crunchy tasty great
# Predicted summary:  not bad but not great
#
#
# # 177
# Text: previously bought medium size product put bristle boy chihuahua loves rings tiny dog powerful chewer picture smaller gnawhide rings looked like diameter thicker teeny tiny eating pretty disappointed size personally would love medium rings thicker last longer 10 minutes
# Original summary: forget the smallest size
# Predicted summary:  dog loves it
#
#
# # 178
# Text: heinz beans first time morning part traditional beans fried egg toast breakfast must say lives hype grew eating campbell pork beans grand scheme things much difference heinz beans distinctly richer cleaner taste campbell without extra salt hfcs find canned beans tomato flavor really shines br br note although take away stars product review supposed product amazon shipping item leave lot desired much larger box necessary padded standard pillow packing popped time shipment reached half cans dented quite badly
# Original summary: a distinctly richer cleaner taste
# Predicted summary:  great beans and taste
#
#
# # 179
# Text: actually favorite community coffee would evangeline blend sale never tasted bad community coffe yet thought would try still prefer dark roast coffee good medium roast variety nice change would willing try community coffee sale icing cake life short drink mediocre coffee drink community get best true taste new orleans
# Original summary: a great taste
# Predicted summary:  not a fan
#
#
# # 180
# Text: searched google found k cups price reasonable exceptionally fast delivery pleased order
# Original summary: green mountain k cup breakfast blend
# Predicted summary:  great coffee great price
#
#
# # 181
# Text: absolutely love emeril big easy bold coffee kcups enjoy alot flavor coffee disappointed also find decaf excellent thank
# Original summary: s big easy bold coffee k cups
# Predicted summary:  love this coffee
#
#
# # 182
# Text: really different read glad anne tenino continued write series even go beyond third installment issues presented well written writing impeccable anne made love paul little ore definitely love trevor uh beginning must read
# Original summary: a wonderful story
# Predicted summary:  another great book
#
#
# # 183
# Text: authors book done wonderful job pulling together bounty dental health information condensing straight forward little guide book covering tooth care infancy elderly written easy understand format little book perfect anyone interested dental health approximately 27 pages contains wealth information causes tooth decay tailor personal oral care treatment plan combat treatments detailed book require professional medical treatment others much detailed prevention must dental health reference guide
# Original summary: a very helpful guide to dental health
# Predicted summary:  a great resource for all ages
#
#
# # 184
# Text: would like read claudia family meeting fred also wedding also fred recovered fortunes family reaction claudia
# Original summary: good but too short
# Predicted summary:  a good read
#
#
# # 185
# Text: drama intrigue suspense first book author tells amazing story characters try deal move lives horrible ordeals happy surprises drama stress wham another twist family secrets come cannot wait next book exhilarating series
# Original summary: just keeps getting better
# Predicted summary:  a great read
#
#
# # 186
# Text: rose wonderful character serious book funny fun ride one books love main character trouble gets keep reading books nice romance intertwined sweet sad character evolves book getting stronger deal life
# Original summary: enjoyed all books
# Predicted summary:  a great read
#
#
# # 187
# Text: true eat gravely affects aging process body tasty junk foods really hard resist many us convinced foods eating additives manufacturers adding healthy fact book help choose eat drink order look young healthy
# Original summary: you are what you eat
# Predicted summary:  raw food for the health
#
#
# # 188
# Text: great product super picky family perfect one son loves iced cookies likes plain ones great us variety eaters reason one minus score cookies arrived melted though probably fault ordering middle 100 degree days keep mind ordering overall great product love snack size great amazon offers items
# Original summary: good product but it melted
# Predicted summary:  great product great price
#
#
# # 189
# Text: book packed full information dealing candida yeast explains lot test much affect health last part cleanse part book simple put together recipes
# Original summary: wow a book packed full of
# Predicted summary:  great recipes for beginners
#
#
# # 190
# Text: tea mild really taste great could definitely see drinking everyday mainly use loose leaf teas find tea bags useful office need quick fix tea great value bags individually wrapped smell great tried two three steeping one bag loose caffeine first steep taste really good br quick note add boiling water tea water 200 degrees sure exact temps get water boil let water sit 3 minutes pour steep tea two three minutes second infusion let water sit 30 seconds minute works br recommend tea highly think like
# Original summary: a great tea for the money
# Predicted summary:  good taste good value
#
#
# # 191
# Text: bad looking forward episodes two rei looks adorable perhaps get dream see loyalty lies
# Original summary: ohh not bad
# Predicted summary:  i liked it
#
#
# # 192
# Text: huge fan series cannot go wrong great story characters sex love wait new additions
# Original summary: love this series
# Predicted summary:  love this series
#
#
# # 193
# Text: found story unbelievable man told sister dead sixteen younger shows blue much explanation given occurred supposedly make long lot sister happy comes plan employee pose secretary order make sister happy worry happiness oh please seen years believed dead big reason lie conversations contrived none characters realistic conversations story slow finish reading
# Original summary: truly make believe
# Predicted summary:  a good read
#
#
# # 194
# Text: would recommend book ones looking learning great portraits love book
# Original summary: great book for getting started
# Predicted summary:  great book for the kids
#
#
# # 195
# Text: obsessed series since first book happy say another great read still cannot beat cow squeezing line hard one live great job incredible read
# Original summary: another great story
# Predicted summary:  love this series
#
#
# # 196
# Text: good read continues story daisy feeding assistant latest adventures farm farmer jones installment still trying control everything including employees goes partnership mr barlow wants daisy still pretty hot darn relationship daisy hank well get see another dimension relationship quick read curious next daisy contract nearing end feeding assistant hank daisy run away together farmer jones connive keep longer daisy permanent side effects taking factor seems hank please write ms litt would recommend book read stand alone would suggest reading 2 books series first
# Original summary: feeding the farmer s partner
# Predicted summary:  a great read
#
#
# # 197
# Text: perfect romance novella read christmas season indeed time year gemma juliana writes vividly winter snow families coming together celebration love loss khazan poignant hero lonely overwhelmed loss beloved anna persuade move grief youngest members family show way forward delightful intriguing timeless story perfect twist richly satisfying ending one read read
# Original summary: enchanting christmas romance
# Predicted summary:  a beautiful story
#
#
# # 198
# Text: read reviewed several books publishing kindle book original info found books numerous original info found book said problems book amazon custom formatter software format yourbook kindle free download also book formatters doit fee perfect book one pretty good price reviewer new kindle book entitled sex education adultssecrets amazing sex happily ever
# Original summary: i disagree with the one star review
# Predicted summary:  great book for kindle fire hd
#
#
# # 199
# Text: son enjoyed learning sea turtles know many different types especially enjoyed fun facts turtle
# Original summary: wonderful book on sea turtles
# Predicted summary:  great book for kids
#
#
# # 200
# Text: series first read roxanne st claire definitely back visit barefoot bay books series book great escape perfect beach wishing near beach
# Original summary: did not want it to end
# Predicted summary:  another great book
#
#
# # 201
# Text: took surprise one really unique story telling heart soul end
# Original summary: quite simply different
# Predicted summary:  a great story
#
#
# # 202
# Text: dogswell brand treats best found gluten scare searched natural ingredients treats found loves even though made china continually tested us quality control always passed dog alergies two basic ingrediants worry also picky eater comes treats takes every time
# Original summary: my dogs favorite treats
# Predicted summary:  my dog loves these
#
#
# # 203
# Text: good like drinking glass fresh homemade tea tell natural sooooo good ate shared bus trip
# Original summary: the best tea candies ever
# Predicted summary:  good tasting tea
#
#
# # 204
# Text: granddaughter loves book lots nice pictures facts cuddly pets book recommended cat lovers
# Original summary: my grandchildren love this book
# Predicted summary:  great pictures and pictures
#
#
# # 205
# Text: author tried rhyme rhyming consistent wasnt smooth read story deals issue certainly common women raised daughters would nice author written story without rhyme
# Original summary: i think it would have been better
# Predicted summary:  a good read
#
#
# # 206
# Text: measured door realized would landed world populated giants planet populated drunken giants oh joy comedy slapstick fashion made pleasant diversion alien lands earth backwoods good book give read
# Original summary: short innocuous tale that tickled my
# Predicted summary:  a fun read
#
#
# # 207
# Text: book stats bang ends cliffhanger early scenes seemed tad disjointed got smoothed found fun reading pages 34 royal brat 34 small main story line antics 11 year old menace political intrigue chin empire cutthroat deadly decision strike destroyer wallace party relax crew consequences well worth price
# Original summary: differant but very enjoyable
# Predicted summary:  a good read
#
#
# # 208
# Text: battled one characters lame gave feeling love triangle lol hate em male lead bit really could connect characters depth lil boring sorry bothering next one
# Original summary: hot cover lame characters
# Predicted summary:  not what i expected
#
#
# # 209
# Text: steaks dainty delish know supposed eat three four ounces beef healthy portion size sometimes like splurge eat bit case would suggest purchasing package larger steaks four ounce steaks made marvelously flavorful tender tender need steak knife cut eating flavor pretty good sirloin steaks go good beefy flavor try rib eye instead br br recommend
# Original summary: but delish
# Predicted summary:  great taste and texture
#
#
# # 210
# Text: best sriracha chili sauce ever found garlic tanginess grabs throat says lick trust people must comply purchased product subscribe save program includes 15 discount free shipping bottles measures 9 inches tall weigh 17 ounces want try guess much would cost ship approximately 6 1 2 pounds product including bubble wrap double boxing price per bottle ends 2 63 per bottle puppies shipped good size box usage chili sauce limited imagination say asian bbq added catsup french fries sauces adding heat spaghetti sauce hungry yet p annie pad thai noodles
# Original summary: the best chili sauce ever
# Predicted summary:  best sauce ever
#
#
# # 211
# Text: short point accurate examples aimed kindle publishing requirements general make html documents web pages narrow focus useful focus since fancy html designed web pages going work book produced published kindle ebook
# Original summary: short to the point accurate examples
# Predicted summary:  good basic information
#
#
# # 212
# Text: antonio lone attracelli sister fight independence along comes brett used getting way two explosive personalities waiting happen fighting brothers handsome sexy hardheaded man
# Original summary: i love it
# Predicted summary:  a great read
#
#
# # 213
# Text: could find variety flavors town got everything wanted one location great transaction
# Original summary: what a hit with the kids
# Predicted summary:  best candy ever
#
#
# # 214
# Text: whew book hot really enjoyed prefer book well written sex scenes definitely delivered graphic books may
# Original summary: loved this story
# Predicted summary:  hot hot hot
#
#
# # 215
# Text: purchased candies key west themed party awesome really taste like key lime
# Original summary: they really taste like key lime pie
# Predicted summary:  great for kids
#
#
# # 216
# Text: pleasantly surprised smooth tastes salty like others tried without odd aftertastes nice clean finish make feel full drank fruit juice
# Original summary: smooth and not too sweet
# Predicted summary:  good taste but
#
#
# # 217
# Text: always loved movie ever since first came bought fiance favorite move one favorites recommend movie anyone always loved comedy michael keaton great beetlejuice
# Original summary: love this movie
# Predicted summary:  best movie ever
#
#
# # 218
# Text: best pizza crust best gluten free pizza crust best pizza crust ever followed recipe previous reviewer gave less liquid problem veggie pizza crust got little soggy problem crust edges still crunchy pepperoni olive perfect crust thin crisp course oh tasty cannot wait try next time grill veggies get moisture namaste
# Original summary: big namaste to namaste pizza crust mix
# Predicted summary:  best pizza crust ever
#
#
# # 219
# Text: truly enjoyed book love magic element reading garrett characters carryover previous book loved way tied together many twists turns love author surprise fun read cannot wait next one series love happy ending knowledge come
# Original summary: a great romantic suspense with a twist
# Predicted summary:  a great read
#
#
# # 220
# Text: really liked book offers practical results oriented ways tools achieve anything want tell author organized person organized thinking skills professional planner advice reliable implemented processes many times successful results trust knows talking matter fact already applied 7 principles work project mine already seeing positive results especially appreciated chapter acceptance accepting certain things learning let go longer working many books success tend leave yet important overall great book achieve goal reliable practical way
# Original summary: no nonsense advice for achieving your goals
# Predicted summary:  great guide for beginners
#
#
# # 221
# Text: br dried cherries slightly sweet slightly tart chewy yummy 100 certified organic baked added sugar preservatives chemicals pesticides herbicides gluten free used added sugar might find sweet would like like heaven thing added cherries slight amount sunflower oil probably keep sticking together small even show total fat count 0g fat serving truly healthy delicious snack br br note natural food may contain pits mine good aware protect teeth br br highly recommended br
# Original summary: delicious natural dried cherries
# Predicted summary:  great healthy snack
#
#
# # 222
# Text: ernest dusty voley tanner attempt weather get spot safe landing near leadville one seasick ride snow begins possibility russell made ashore discussions three concerning life rain heart warming sad tanner thoughts pride wise beyond years highly recommended
# Original summary: onboard the resilience
# Predicted summary:  a great read
#
#
# # 223
# Text: funny mystery series molly constantly coming funny ecards good guessing murder one stumped
# Original summary: funny great mystery
# Predicted summary:  a fun read
#
#
# # 224
# Text: story teenage girl named olivia upset moving san diego live dad stepmom arrives neighborhood meets cute boy catches attention short story written perspective teenage girl know teenagers talk way words uses sound outdated rather way adults think teenagers talk whenever spoke came across inauthentic distracted actual story story ended abruptly seem like real conclusion story really go anywhere would recommend anyone even 26 pages still waste time
# Original summary: not particularly care for this short story
# Predicted summary:  a little too much
#
#
# # 225
# Text: massive earthquakes caused vampires come hiding vow protect inhabitants towns exchange blood town meeting secretary misty offers blood donor vampire protects town lives figures one time deal discovers good people town raised used willing sacrifice make vampire ivan happy ivan wants misty blood wants bed submit seductions forces issues first mean waking find tied bed lot say moving forward suggests force misty soon finds enjoying time ivan finds given people trying impress vows stay could connect either characters one maybe short jump right meat story know story engaged
# Original summary: could not connect with the characters
# Predicted summary:  a great story
#
#
# # 226
# Text: two cats eaten purina one six years coats shiny look healthy lots energy eleven years old started feeding purina one first ingredient label chicken also artificial colors flavors unlike pet foods manufactured united states enough reasons choose particular food think even though purina one best best cat foods good value price cats love male kitty eat anything else tip anyone introducing new food kitty introduce food slowly mixing little new food old food increase amount time feed kitty eventually eliminating quantity previous food help alleviate stomach upset kitty may experience new food
# Original summary: my two kitties love purina one
# Predicted summary:  my cats love it
#
#
# # 227
# Text: reluctantly giving 4 stars several spots background repeated unnecessarily wanted enjoy book liked premise sometimes writing bogged overly simplistic detail nevertheless probably get third book enjoy type 34 34 story
# Original summary: the story continues
# Predicted summary:  good story but
#
#
# # 228
# Text: great rich flavor long time user 25 br breakage rate never cups br noticed cups seem puffy br air perhaps problem
# Original summary: 1 of 5 kups breaks
# Predicted summary:  great coffee but
#
#
# # 229
# Text: objective useful tutorial mac users interested formating texts kindle must read book
# Original summary: a very useful tutorial
# Predicted summary:  great for beginners
#
#
# # 230
# Text: much enjoying fogchaser flavor great br br posts mentioned look like traditional k cup incidentally price great k cup royalties right works like kcup coffee packaged bags freshness company thoughtfully included plastic food storage container storing open package sure cheap container works think really nice touch company ensure opened package coffee stays fresh br br price half paying k cups supermarket pleased household goes 8 10 cups day savings significant us 5 stars br br happy
# Original summary: good price and good coffee for keurig
# Predicted summary:  great coffee great price
#
#
# # 231
# Text: awesome part 3 damn great ending book ayesha rahiem back together got mom two siblings finally happy
# Original summary: good good good
# Predicted summary:  love this series
#
#
# # 232
# Text: glad old story terrifying many levels 27 people confined rubik cube style box reason imprisoned though evil master cube declares different tasks might cause one life lost unless prisoner commits suicide prior earliest moments task case person uses gun comes cube die choice save lives taking none 27 remember got first one residents remembers master decides speed tasks man gets surprise love good twist plot betcha see one comes
# Original summary: if this is what the future holds
# Predicted summary:  a great read
#
#
# # 233
# Text: wish author used imagery could visualize characters main character definitely accepted fate interesting change
# Original summary: a good story
# Predicted summary:  a good read
#
#
# # 234
# Text: small town offer love sexy creative explosive heart felt one little town much find love takes breath safe know matter life may bring help fight keep town alive live journey woman see love feeling find travel ajourney warm heart help believe true meaning family also series read one
# Original summary: the amazing journey
# Predicted summary:  a great read
#
#
# # 235
# Text: bad really regency era touch supernatural powers heroine forced retrieved supposedly powerful statue risking life ready gain effort hero came snatching ticket saving mother poverty outwits bad guys moves closer good guys came rescue hero heroine fell love long lost family memebers friends popping sweet sentimental read writing good though might check author books reading book thought check author books series boy learn well stick short stories first book series wild heart though interesting filled repeated miserable musings used plot like using villian prolonged suspense boy used lot plot drawn would great short story guess human nature hit miss
# Original summary: regency romance with a touch of supernatural
# Predicted summary:  a good read
#
#
# # 236
# Text: jessica bradley life slump hates christmas new year love life non existent twenty seven feeling till computer packs call department help brandon tanner turns jessica cannot believe handsome sexy guy looking like wants next day calls see going firms new years party jessica going attend due pervy boss agrees go meet brandon sweet story author liked characters idea think chance romance life way surprising really quick read nice
# Original summary: short but sweet
# Predicted summary:  a sweet story
#
#
# # 237
# Text: wish would thought check reviews buying since seems consensus stuff far cry horchata dull chemical plastic taste wife says tastes like sunscreen spot except mouthfeel sunscreen rich creamy watery br br defense powder smells great try repurposing potpourri
# Original summary: sunscreen or maybe plastic
# Predicted summary:  tastes like plastic
#
#
# # 238
# Text: finished animal crackers elle hayley weaver top world walks boss office get promotion worked night day life goes gutter starting boss saying fired boyfriend saying job money homeless jobless job comes way house sitting famous movie star expenses paid food paid look job cushy job hard karma gods finally smiling fun read start finish story lots humor good old fashioned romance mixed crazy animal antics great story anybody
# Original summary: feel good fun story
# Predicted summary:  a fun and entertaining read
#
#
# # 239
# Text: awful love vanilla nuts looking forward tea tastes artificial medicine like price per box good compared store price certain stash flavors stores worth
# Original summary: decaf vanilla nut creme tea review
# Predicted summary:  great taste but expensive
#
#
# # 240
# Text: first experienced nantucket nectars apple juice workout health club hooked first drink crisp best apple ever pleasure br biting reduced juice bottled br cannot describe words good juice suppose standard apple juices measured none compare nantucket nectars apple juice simply best
# Original summary: best apple juice you will ever taste
# Predicted summary:  great taste and great price
#
#
# # 241
# Text: girls love stuff play around different brands finally found could happier also automated delivery convenient
# Original summary: nom nom nom
# Predicted summary:  kids love it
#
#
# # 242
# Text: left wanting first action packed paragraph kept wondering would happen next ended happens next got read next one
# Original summary: way to short
# Predicted summary:  a great read
#
#
# # 243
# Text: reviewed mrs condit friends review blog top bidder fun sexy little hammer short story brings together master august new sub kurt christmas eve fundraiser xavier bids large sum get evening kurt winds whole lot evening lot hot sex story august kurt get know intimate ways august watching kurt since came hammer club kurt oblivious kind dom went job wishing exactly kind dom auggie 8217 short story packed lot action romance good one
# Original summary: hot action and romance
# Predicted summary:  a great read
#
#
# # 244
# Text: good story attraction instant hannah michael problems class rank kept story swinging back forth love wins
# Original summary: the accidental princess
# Predicted summary:  a good read
#
#
# # 245
# Text: calm lived name fact also helped son muscle twitches highly recommend trying anxiety muscle issues purchasing online saved almost huge amount money
# Original summary: just what i expected
# Predicted summary:  great for diabetics
#
#
# # 246
# Text: dog addicted actually fully digestible hurt anything purchased everywhere planet buy
# Original summary: great prices fast delivery
# Predicted summary:  dog loves it
#
#
# # 247
# Text: uh wow could put one heart throat entire time read episode cried wanted cry ending sure want continue character episode make yet cannot read episodes come know happens
# Original summary: love and decay episode six
# Predicted summary:  wow wow wow
#
#
# # 248
# Text: wow expected fantastical story filled wool much whimsy found multiple short stories concerning fellow seemed sad unlucky unlucky reputation lucky situations story proved spell binding wonderful included adventure suspense gun blazing romantic absolutely loved ending wonder become gunman lady love read one see remain unmoved dare ya
# Original summary: love story i thought not at first
# Predicted summary:  a great story
#
#
# # 249
# Text: enjoyed book great read left wanting know happened admitted loved would great experience wedding
# Original summary: a great book
# Predicted summary:  a great read
#
#
# # 250
# Text: received added collection variety flavors great allows find really like prior buying full box recommend starting coffee maker want add variety stash
# Original summary: great way to find new flavors
# Predicted summary:  great variety pack
#
#
# # 251
# Text: possible good quality life course commitment honesty required since must effort improve feeding among others book overviews things need change order control disease recommended
# Original summary: change to a healthier life
# Predicted summary:  great insight into the past
#
#
# # 252
# Text: great book help get acquainted kindle fire hd author tells reader lot information help understand use kindle many ways lot information book stores kindle
# Original summary: big help in understanding kindle fire hd
# Predicted summary:  great for beginners
#
#
# # 253
# Text: miss eden garden fun read delightful mix romantic suspense mystery adams skillfully wove threads story wondering whodunit way end many characters motive opportunity fun ride way story discovery culprit looking forward reading author
# Original summary: digging in to a fun read
# Predicted summary:  a fun read
#
#
# # 254
# Text: book well written attempts fuse mythology holy scripture prove dubious claims book use much ancient mythology studies various biblical manuscripts try prove giants spirits humans falls short basis whole book 4 obscure verses book genesis author goes far introduction assert one better argue assertions since arguments could used redemption salvation trinity etc issues even three stars given interesting ancient writings
# Original summary: interesting at best
# Predicted summary:  a good read
#
#
# # 255
# Text: nicola easily captured attention book even though accidentally read spoilers still able get lost story challenges lucinda face increase unbearable level book seems almost impossible since already ton crap plate previous 5 books sure lip poked several occasions reading complaint detailed surveillance vampire wearing skip parts long unnecessary descriptions usually right plot thickens provide foreshadowing waste valuable reading time depends reader much time go ahead buy 8 wish since obviously must finish whole series search nicola books start well happy reading
# Original summary: entertaining as always
# Predicted summary:  not what i expected
#
#
# # 256
# Text: noticed many tells reviews number sites mentioned friends occasion open discussion liked story main idea believe lot truth maybe silly banter make fiction brings ideas aware thought provoking read discuss friends
# Original summary: wake up call
# Predicted summary:  a great read
#
#
# # 257
# Text: loved book downloaded morning read one sitting real problem book leaves hanging complete story way thinking want book two want rational note probably ya book main character high school summer story going work partying friends amongst things bit romance issues parents well written story pulls carries along recommend maybe book two comes
# Original summary: wow where is the sequel
# Predicted summary:  a great read
#
#
# # 258
# Text: never read threesome book holy crap like double romance instead weird weirdly beautiful feel creepy even saying read
# Original summary: holy crap this was amazing
# Predicted summary:  i loved this book
#
#
# # 259
# Text: max jensen new school used bullied around knows expect jimmy davidson face challenging willing spend new year new school dodging bullies agrees meet school get told deceased murderer home certain time get blood stained paint house say means left alone gets bargains hoax scare truth rumors
# Original summary: beware of the dark
# Predicted summary:  a great read
#
#
# # 260
# Text: thought knew popcorn bag mind arrived much different br br large use business hand bags probably equivalent movie theater medium complaint except hold much give popcorn consume runs fast gets tossed br br constructed cheaply usually sides popcorn bags pleated hold good amount small much easier load ones difficult fill bottom fold make bag square either like popcorn bags instead sealed opens oval br br cannot complain product cheap job excellently would like warn anyone considering though giving commercially 4 bags clean machine
# Original summary: not quite what i was expecting
# Predicted summary:  great popcorn for the price
#
#
# # 261
# Text: think like son purchsed easy healthy snack think much difference flavors sour apple fairly tart overall think good really great way bring serving fruit anywhere
# Original summary: tasty portable snack a little tart
# Predicted summary:  great for kids
#
#
# # 262
# Text: peek world wealthy caring birdie amazing young woman total contrast members family taken spoiled entitlement top christian faith ethics forefront influencing choices along way drawing loyal friends side needs great loss break friend family addresses homelessness child abuse killer business tactics story moves along colorful likeable characters nice serious bad guys
# Original summary: the good guy gets the girl
# Predicted summary:  a great read
#
#
# # 263
# Text: took foster cat almost one year ago tried almost everything rid diarrhea vets unable diagnose parasite physical problems behavior always appeared happy healthy vets said could food allergy began trying different foods couple months ago bought sd sensitive stomach reluctant ingredients strive avoid foods meal kind well price 40 15 5 lbs year five foods several supplements though desperate sensitive stomach trick noticeable difference within weeks stools completely normal weight gain constant regardless food attribute science diet brand br br drawback two cats prefer food original brand quite expensive three cats two gained weight product appetite appear increased
# Original summary: expensive but it worked
# Predicted summary:  great for sensitive stomachs
#
#
# # 264
# Text: hard rate something tested warranty use able judge program kindle fire
# Original summary: do not know what to say
# Predicted summary:  kindle fire hd adapter
#
#
# # 265
# Text: far much unreliable information gardening internet book skillfully remedies problem clear concise direct accurate instead going hundreds different websites comparing verifying hundreds different techniques read book everything need know single place writing high quality easy understand overwhelmed overdose information available online start finish book
# Original summary: accurate and straightforward
# Predicted summary:  a great resource for any business
#
#
# # 266
# Text: think could get better shocks us look dorothy side story shows us love triangle jase hawk tears apart inadvertently helping find way yet raw gritty shows softer side deuce well keep lady
# Original summary: madeline s done it again
# Predicted summary:  a great read
#
#
# # 267
# Text: could liked book really wanted like book enjoyed author style writing like characters immature adults opinion
# Original summary: did not care for the characters
# Predicted summary:  good story line
#
#
# # 268
# Text: read many different levels themes werewolf mating love stories author brought unique aspect looking stories really enjoyed reading way author perspective bringing couple together
# Original summary: very impressed with this new author
# Predicted summary:  a great read
#
#
# # 269
# Text: cats love brand trust cats get canned food week adversely affect kitty tummies litter box dry food meals
# Original summary: cats love it
# Predicted summary:  my cats love it
#
#
# # 270
# Text: great diet cant snack unhealthy stuff smart fries great snack fix flavors good
# Original summary: smart fires for sure
# Predicted summary:  great snack for the diet
#
#
# # 271
# Text: review leading newspaper hooked intriguing two part thriller clever premise epic page turner written wit compassion highly evolved characters kicks author sam manuscript taken away life threatening circumstances moment life never key question posed sam tracking life saved last moment nothing seems sam know trust even closest conspiracy pieces puzzle start fall place sam path collides agent adel al heads team hot trail world leading terrorist abu really great thriller hard hitting vein vince flynn lee child intelligent shades le carre falls must read category conspiracy thriller junkies daily telegraph spot glad followed recommendation
# Original summary: review was spot on
# Predicted summary:  a thrilling read
#
#
# # 272
# Text: add little italian spice batter tastes great easy make recommend anyone gluten free diet craving pizza make crusts pizza pans add toppings freeze later family craving pizza time short
# Original summary: the best gluten free pizza crust mix
# Predicted summary:  great gluten free pizza crust
#
#
# # 273
# Text: great coffee want smooth flavored k cup add small amount milk coffee flavoring enough
# Original summary: tasty nice aroma smooth taste
# Predicted summary:  great coffee great price
#
#
# # 274
# Text: rate harshly 3 stars means average bought worth price free ok buy one people little annoying really want read hawks story also seemed unrealistic two people would take long figure things
# Original summary: for 0 99 its ok
# Predicted summary:  not worth it
#
#
# # 275
# Text: read four books series would recommend everyone stories work riveting could put
# Original summary: fire the akasha series
# Predicted summary:  i loved this series
#
#
# # 276
# Text: cherries good flavor great value compared fancy jars usually sell find put glass jars share friends high sugar content syrup keep well especially fridge br br update may 2012 ate last refrigerated 2009 cherries week ago ill effects still delicious packed new batch six 12 oz jelly jars little syrup left drizzle ice cream next days
# Original summary: cherries and still good after three years
# Predicted summary:  great product great price
#
#
# # 277
# Text: hitting coach jake player field falls sean flannery little sister siobhan romance writer freaks commitments love relationship daughter enlists help win siobhan back
# Original summary: another good installment of mustangs series
# Predicted summary:  a great read
#
#
# # 278
# Text: love marzipan love apricot cannot ask perfect combination taste heaven without wait wish easier find
# Original summary: a little bite of heaven
# Predicted summary:  best caramel ever
#
#
# # 279
# Text: enjoyed story parts much little fast paced author covered lot ground short period time started getting really story liking characters wanting wish longer would like know sunny david get better acquainted town bf enjoyed sunny transformation nerd said 34 34 crowd confident beautiful women wish knew shifters town sunny family etc little shared however like difference uniqueness shifters author created rather 34 normal 34 shifter stories usually read thought idea story great really felt much left unsaid shared 3 5 stars review nanee upallnightreadallday blogspot com
# Original summary: 3 5 stars
# Predicted summary:  a great story
#
#
# # 280
# Text: really enjoyed story really like author glad guys let get away
# Original summary: dinner for three
# Predicted summary:  i liked it
#
#
# # 281
# Text: nearing end author disappointed let redeemable liked humor h h hot cold attitude got nerves much till spoiler wedding enjoying ignoring silly parts book part frustrating think heroine silly times liked determination honesty something hero never doubted potential would rated higher unnecessary misunderstanding towards end could even ignored back issues sex would affect past silly little things got frustrated though moments book really liked simply liked overall know would recommend glad read free warned let expectations get high still better read beauty beast type stories read past
# Original summary: in general i liked it but
# Predicted summary:  not what i expected
#
#
# # 282
# Text: son loves oatmeal 16 months eating consistently abt 7 months great texture great transitional food stage 3 toddler
# Original summary: great toddler breakfast
# Predicted summary:  great for baby
#
#
# # 283
# Text: andrew refreshing clarity insight mention practicality experts lack show rock star helps tune guitar
# Original summary: short and sweet
# Predicted summary:  a great read
#
#
# # 284
# Text: bound blood short story written cynthia eden published ebook format short story fooled get feeling much personally ms eden write stories featuring great characters larger life shifter vampire also realistic swear could walk door moment story fast paced deeply engaging fun times thrilling ride want take loved whole book complaint get another story right away want see characters recommend bound blood fans paranormal romances great characters enthralling storyline delighted bought great short story reviewed wendy 4 1 2
# Original summary: a great awesome shifter romance
# Predicted summary:  a great story
#
#
# # 285
# Text: rachel funny hell book also speaks heart read one sitting want put kids sound adorable loved stories guy turns lived fairly close one point time sure wish met back think would become good friends sounds like blast hang rachel reading orange juice vodka coming
# Original summary: cracks me up
# Predicted summary:  a great story
#
#
# # 286
# Text: lapses proofreading spoiled otherwise good reading experience sex scenes became tiresome redundant overall character development engrossing wolf world created
# Original summary: very good with some lapses in proofreading
# Predicted summary:  good story but
#
#
# # 287
# Text: little bit prayer church make story christian story love scenes explicit
# Original summary: not a christian romance
# Predicted summary:  a good story
#
#
# # 288
# Text: book hot handle cole hart always thing enjoy walking cole stories thisseries young man name fly take much young life handle great strength cant wait see drama going take us
# Original summary: you have been dethroned
# Predicted summary:  hot hot hot
#
#
# # 289
# Text: really enjoyed thought put lot truth story even fictional get whisked fairy tale come real lifebut escorting offer different view place
# Original summary: mmm must get the rest
# Predicted summary:  a good read
#
#
# # 290
# Text: disappointed new taco bell creamy sauces first tried ranchero sauce good sauce creamy jalape ntilde sauce slightly better taste still impressive one thing jalape ntilde flavoring quite mild prefer much spicier kick food best way describe taste manufactured taste like freshly made sauce much sauce overwhelming spicy factor bottled taste would ruin good mexican food made fresh ingredients taco bell brand love canned refried beans original bottled hot sauce creamy sauces however impressed
# Original summary: an ok condiment if used sparingly
# Predicted summary:  not bad at all
#
#
# # 291
# Text: avid celestial tea drinker number years br far favorite mine changed br company decide package differently also br added blend white tea opinion ruined perfectly good br product br tea seems weaker smoother br past year tea prior change difficult find local br grocery store purchased online fully satisfied last shipment arrived br new tea sent needless say buying unless company returns br back original superior far br oh cannot companies leave things alone new necessarily mean better case br rings true
# Original summary: disappointed to say the least
# Predicted summary:  not a good tea
#
#
# # 292
# Text: touching story young mother luck unhappy man lost family find reach touch others turn heal nice story christmas
# Original summary: a christmas to remember
# Predicted summary:  a christmas story
#
#
# # 293
# Text: writing good usual gfy romance much slots given sex could better invested characters development importantly plot afterall cops story really opportunity lost like characters writer could done much flushing characters letting personalities drive romance giving us pieces background enough cops story writer could really made plot line interesting
# Original summary: could have been so much more
# Predicted summary:  good story but
#
#
# # 294
# Text: made new york cheesecake vanilla awesome put vanilla custards cakes best ever made wonderful texture strong alcohol smell real madagascar vanilla vanilla either alcohol artificial ingredients real pure vanilla makes food taste better without aftertaste best quality vanilla buy comes big bottle
# Original summary: excellent quality without strong alcohol smell
# Predicted summary:  great vanilla taste
#
#
# # 295
# Text: great book lots twists turns great characters great action lots romance could better loved
# Original summary: wronged a historical southern romance
# Predicted summary:  great mystery and romance
#
#
# # 296
# Text: another great read helen scott taylor love books enjoy books kind writer makes laugh brings tears happy ending
# Original summary: a family forever
# Predicted summary:  another great book
#
#
# # 297
# Text: love book 4 series lions favorite shifters arkadia much humor live book beautifully offsets drama still underlying mystery arkadia hit upon book also amazing relationship makes stop want three men varying personalities seem work together one complements fitting three unit book definitely ranks one absolute favorite series
# Original summary: i love book 4 in this series
# Predicted summary:  great series for the series
#
#
# # 298
# Text: wife cats love temptation treats eat becuase gluttons obvious keen taste way makes feel br br noticed difference hairballs using treats need something hairballs get brown barley malt paste stuff works real good cats actually like taste
# Original summary: hairball formula does not seem to tasty
# Predicted summary:  my cat loves these
#
#
# # 299
# Text: like craisins dried fruits chewy like raisins raisins kind boring common cherries fantastic received couple orders far shipping packaging perfect come single 4 pound bag split smaller bags one big zip lock bag sometimes give gifts sandwich baggy full people really happy receive many different things use baking biscotti eating snack like snacks toppings cereal br br probably would purchase normal price tight budget accustomed getting discount subscribe save discount total 20 free shipping
# Original summary: really enjoy these dried cherries
# Predicted summary:  great taste and price
#
#
# # 300
# Text: love love love use food face body hair base homemade creams lotions love love love say order 16 oz jar mo 32oz every 2 mos tried 2 brands barleans store bought junk louana knew better staple pantry 2 years cannot go day without coconut oil small glass jars bathrooms labeled body know hand dip use stainless steel pans prior cooking pretty much anything use brownie mixes pancake mixes anything love br likely never switch another brand like like sticking
# Original summary: the only coconut oil in my pantry
# Predicted summary:  love this product
#
#
# # 301
# Text: bought cats 2 3 years old longer act like kittens let watch put food sat show get food well several times cats looked like crazy maybe cats spoiled kinda knew wait long enough would put food bowls ignored toy entirely said work food think tried using treats still work eventually gave friend got kitten kitten played reached certain age think concept works dogs
# Original summary: my cats ignored it
# Predicted summary:  my cats love this food
#
#
# # 302
# Text: deep autumn heat barrett delivers rich mix sizzle mystery heart see booktrib romanticreadsandsuch
# Original summary: deep autumn heat
# Predicted summary:  a great read
#
#
# # 303
# Text: worst tasting coffee ever made distinctly metal taste would never buy
# Original summary: suisse mocha decaf sugar free
# Predicted summary:  worst coffee ever
#
#
# # 304
# Text: fine read looking something mindless would actually recommend friends lot plot brought back happens prologue even though characters old enough analyzed happened better considering much time passed little eye roll inducing
# Original summary: okay for what it is
# Predicted summary:  not what i expected
#
#
# # 305
# Text: love loyalty respect love whole volume 1 thru 4 waiting loyalty come
# Original summary: i love it
# Predicted summary:  love this book
#
#
# # 306
# Text: would recommend lover books like dark trilogy extinct plan read author tey available
# Original summary: different but i liked it
# Predicted summary:  dark and twisted
#
#
# # 307
# ...
# Text: used able buy carmel suckers sams able find locally search found personally think price high since could find elsewhere paid got ordered timely fashion complaints would use seller product
# Original summary: suckers ever
# Predicted summary:  best price for the price
#
#
# # 957
# Text: bought three flavors try flavor far worst hate throwing food away could eat white cheddar ok like looking sweet snack filling yummy would go cinnamon flavor love packs low carbs sugar good amounts fiber protein
# Original summary: not this flavor
# Predicted summary:  tastes like yuck
#
#
# # 958
# Text: impressed author 8217 prose mr jester delivered compelling somewhat disconcerting book author true wordsmith brings terrifying images events life admit totally freaked book main characters teenage guys really jumped page easy identify book certainly squeamish love good old style blood guts one disappoint recommendation would read one right bedtime
# Original summary: old style blood and guts
# Predicted summary:  a great read
#
#
# # 959
# Text: love story book never bored derek sara story length even though short story drama book story even though started sara remembering concept story good love story flows characters love characters made easy like love derek personality course character sexy hot love story ended start last everything great ms renee really great job making book captivating interesting leave wanting
# Original summary: interesting and captivating
# Predicted summary:  a great story
#
#
# # 960
# Text: find book perfect ultimately neat organized chapter dedicated specific cleaning task lisa systematic way cleaning house way overwhelming thinking lot cleaning one thing noticed cleaning tips really secrets like cleaning bathroom favorite part using chemical based products home products strong also much effective like shares home made cleansers simple household products would believe use vitamin c tablets clean toilet bowls cool
# Original summary: not bad for of house cleaning secrets
# Predicted summary:  great tips for the beginner
#
#
# # 961
# Text: son loves oatmeal go quickly glad able order pack six canisters previously bought product boxes canister design works much better boxes boxes always felt throw away last several tablespoons packaging poorly designed canisters work well double cheap toy oatmeal gone br br taste seems good though often add cinnamon good measure glad know son getting dha regular diet food allergy concerns aware product contains b lactis cultures
# Original summary: good oatmeal well packaged
# Predicted summary:  great product great packaging
#
#
# # 962
# Text: fan elliot kay work novella exception writing top notch filled humor action even steamier 34 action 34 unlike author works clocks around 110 pages notice star count changed work clearly well done fan tabletop rpgs larry niven dream park series right alley however short may want look elsewhere first get bang buck though author merely allude said banging
# Original summary: but too short
# Predicted summary:  great addition to the series
#
#
# # 963
# Text: purchased seasoning last spring local grocery used everything pork seafood veggies burgers name summer long imagine dismay went restock find store carrying grilling season granted great grilled food used many ways little eggs amazing zing spice blend hot overrides flavors food also used several emeril blends like one better also although stated blend gluten free cannot tolerate gluten problems using product used liberally meats easy get restaurant blackened flavor spice absolutely love happy see amazon reasonable price stocking
# Original summary: fabulous useful in so many ways
# Predicted summary:  great for the price
#
#
# # 964
# Text: box set full action hot steamy since read first 3 books series read book 4 saw set buy getting book 4 5 6 well sale steal worth every penny great job ms reus
# Original summary: stone security series box set volume 2
# Predicted summary:  hot hot hot
#
#
# # 965
# Text: enjoyed story much wish telling stories others story bad leave group brother partner told part group kept badges kind following rules ask yes wanted tell little told give team stay team try another books see fairly thought confusing self looking others maybe getting 33 50 pages book worth anyway maybe someday writes real book maybe try
# Original summary: a bear not your average fox bbw
# Predicted summary:  good story but
#
#
# # 966
# Text: must admit idea genre put short unusual story original story tells alyssa city girl became farmer wife one special bull life farm since short read cannot say much fear giving away plot looking different quick read would well written author knowledge tangible throughout story birth bull highlight book
# Original summary: different but excellent story
# Predicted summary:  a good read
#
#
# # 967
# Text: really expected one least favorite could see sheehan could shape story way everyone came happy least hawk dorothy made together happy together know never underestimate madeline sheehan story told 7 years christopher birth suprised thought would tell whole story start finish infamous love triangle however actually good job keeping story flowing left ish 34 unattainable 34 providing us brief glimpses past thereby painting background current situations hawk dorothy jase awesome roller coaster story still reeling epilogue get sneak peak next book 34 undying 34 clue pairing zz still shock choice bravo madeline
# Original summary: better than i had hoped for
# Predicted summary:  a thrilling read
#
#
# # 968
# Text: cats go crazy food buy 2 pounds time seems like small bag lasts 2 weeks least also get canned raw probably act like filled bowl treats get excited glad love eat really healthy high protein food also feed acana blue wilderness rotation one backflips guess 50 protein literally yell try smack bowl hands place floor lol highly recommend food part cat diet br br also well aware p g buyout really care
# Original summary: screaming cats want
# Predicted summary:  my cats love it
#
#
# # 969
# Text: cosco month sold searched found amazon thank wait 6 weeks delivery dont know maybe made hand worth wait
# Original summary: best cookies on earth
# Predicted summary:  best price for the money
#
#
# # 970
# Text: loved every book series even though story brought tears times would like seen bit adam mercy finding life together definite must read burke
# Original summary: what a great series
# Predicted summary:  love this series
#
#
# # 971
# Text: recently upgraded 45 pound pit terrier mix power chewer industrial chewer toy short list toys cannot immediately destroy loves love br br thing toy us strictly outdoor toy makes crazy mess string chunks bits girl able spend time backyard since getting mammoth fist ball keeps occupied enough prevent eating swing set mulch grass kid toys digging name br br highly recommend chewers
# Original summary: perfect for chewers
# Predicted summary:  great toy for the price
#
#
# # 972
# Text: informative book gives clear way write section gives examples includes cover letter prep interview overall great reference trying apply jobs better resume
# Original summary: great reference for resume writing
# Predicted summary:  great resource for beginners
#
#
# # 973
# Text: loved friends like single holy mother hope sequel want see works big boss
# Original summary: totally hot and sexy
# Predicted summary:  a great read
#
#
# # 974
# Text: hard believe jess could taken old boy jess good hearted honest people plus good tipper good service feel good left colourful town paradise good hands leg
# Original summary: the best whiskey did another fine job
# Predicted summary:  a good read
#
#
# # 975
# Text: decided buy petco amazon instead going store get little cheaper saved us trip surprise product color consistency purchased stores last years make matters worse one cats suddenly developed swollen lower lip due allergic reaction makes us wonder response obviously different product received fed br br update 5 27 10 noted first two cases different stores next order normal color consistency looks like quality control issue update experience
# Original summary: poduct than what is in the store
# Predicted summary:  not what i expected
#
#
# # 976
# Text: first book new series mandy popular girl high school zeke geek worlds changed drastically run years later mandy maid resort zeke billionaire crush mandy years desperately needs financial help redeem open zeke realistic storyline many women relate
# Original summary: the high school drama continues
# Predicted summary:  a great read
#
#
# # 977
# Text: story unbelievable obvious author tries evoke mystery reality uses cliches bad romance novel brooke self absorbed moron gets drugged twice accepting drinks men yet described brilliant ummm perhaps much author spends time telling reader perfect brooke amazing family rich yet give character truly redeeming qualities feels like poorly written adult version sweet valley high book cannot tolerate poor writing beyond poor
# Original summary: one stupid leading lady
# Predicted summary:  a great read
#
#
# # 978
# Text: really love tim rourke expecting really enjoyed cannot wait read entire series
# Original summary: o rourke does it again
# Predicted summary:  love this series
#
#
# # 979
# Text: first jl merrow book really liked plot good really felt paul tried get memory sanity back background iceland fascinating surrounding characters well written part looking forward reading ms merrow works
# Original summary: very good read
# Predicted summary:  a great read
#
#
# # 980
# Text: perfect combination erotic sci fi excitement mixed unworldly everlasting love cannot wait next book
# Original summary: wow so different and so good
# Predicted summary:  a great read
#
#
# # 981
# Text: another great book love characters great suspense humor romance added ask read entire series highly recommend
# Original summary: a must read
# Predicted summary:  great mystery and mystery
#
#
# # 982
# Text: wife love cakes betty crocker stores thanks amazon stock good price
# Original summary: not in stores
# Predicted summary:  great product great price
#
#
# # 983
# Text: ebook kindle fire story pretty simplistic okay guess reading genre exactly romance might easy reading another enjoy
# Original summary: a simple story
# Predicted summary:  not for me
#
#
# # 984
# Text: older dog developed allergies hard find dog food works using diamond naturals suspect must changed formula suddenly allergies flared ended ear infection switched dog food loves love ear infection gone itching scratching chewing much less grateful found hope change formula
# Original summary: our dog loves it
# Predicted summary:  great dog food
#
#
# # 985
# Text: received copy story exchange honest review story defiantly dark erotic read enjoy reading taboo erotica kidnapping rape abuse story author beautiful job binding two broken souls
# Original summary: the girl
# Predicted summary:  dark and erotic
#
#
# # 986
# Text: review based actually trying product bag came looks like regular goody bag attached packing labels usually would bother sealed red tape like products sealed professionally
# Original summary: i would not buy this product again
# Predicted summary:  not what i expected
#
#
# # 987
# Text: say wow cannot believe way story began connection main characters comes pages
# Original summary: omg the love
# Predicted summary:  i like it
#
#
# # 988
# Text: 2 dogs use feed dry food friend mine recommended adding olewo supplements dog food really heard supplements pets little research liked found dogs love carrot supplements food smaller dog picky eater would refuse food sometime adding carrots food went crazy finished every bite also feeding dogs href http www amazon com gp product b0083qbwku olewo dehydrated red beets dog food supplement 2 2 pound going try carrots get red beets
# Original summary: great for all breeds
# Predicted summary:  great for dogs with food allergies
#
#
# # 989
# Text: decaf first choice purchased product nice variety want sip cup
# Original summary: great if you prefer decaf tea
# Predicted summary:  decaf decaf k cups
#
#
# # 990
# Text: regular staple house years ago became difficult find stores happy find available amazon
# Original summary: b m baked beans
# Predicted summary:  great breakfast food
#
#
# # 991
# Text: shiloh stark exciting fast paced beautifully written story hard man troubled past become hero sorts american civil war shiloh stark returns south west cannot shrug history violence feels home comparative lawlessness frontier realise despite passage many years still recognised town pierceville especially since continues resolve disputes using pistol soon enough stark bunch vengeful family members hunting kind man beat cowardly retreat scene set fateful confrontation several memorable characters fill stage lora red haired girl gets tangled stark dangerous life rescues find balance realism entertainment depiction characters plot general impressive
# Original summary: a rip roaring read
# Predicted summary:  a great read
#
#
# # 992
# Text: page turner ash oh yeah wait next want see going girl brother messing actually sister simeon responsible happen brother know cherish brother oh man many questions unanswered friend messing ex going waiting patiently
# Original summary: awesome read a page turner
# Predicted summary:  i loved it
#
#
# # 993
# Text: easy make enough curry sauce arround 4 6 orders curry chips french fries
# Original summary: best curry to make curry chips
# Predicted summary:  great for the price
#
#
# # 994
# Text: okay ask dog tie book random dog thoughts happening throughout book awkward dog wrap end book better hearts motion sticky syrupy sweet premise interesting somehow got watered bit ruined thought author listening would say lose animal crutch let writing stand allow
# Original summary: dog tie in
# Predicted summary:  dog did not like it
#
#
# # 995
# Text: thought real gimmick get buy something see sign spend money something sould waste money
# Original summary: not what i thought
# Predicted summary:  not what i expected
#
#
# # 996
# Text: liked product pretty cheezy promotion make think going get free shipping double order finalizing check find let double order want charge shipping
# Original summary: oberto original beef jerky
# Predicted summary:  good product good service
#
#
# # 997
# Text: vinegar great buy bulk save cannot even find balsamic costco quantity price br br balsamic perfect making dressings vinaigrette marinades also wonderful like make reductions glazes want concentrate put squeeze bottle garnishing dishes br br flavor good getting bargain brand balsamic vinegar taste know kind talking basically red wine vinegar food coloring caramel color added order make look like balsamic br br go wrong purchase use balsamic vinegar frequently
# Original summary: great all purpose vinegar
# Predicted summary:  great product and price
#
#
# # 998
# Text: looking ginger tea actually spicy taste ginger found tea sweet tooth per say generally like lot sugar things drink eat although ginger tea sweeten honey cane sugar sweet enjoy
# Original summary: instant ginger and honey tea
# Predicted summary:  too much sugar
#
#
# # 999
# Text: got flour short amount time amazon eagerly made batch pizza dough caputo website pizza made pizza stone 500 degree oven crust light crisp tasty could ask easy stretch work tender dough made morning chilled dough 2 hours making pizza learning chemistry food world facinating next going try add king aurthur pizza dough flavor dough mix try different recipes crusts great flour find favorite one always quest perfection baking 2 2 pound sack last long mountain pizza maker href http www amazon com gp product b0038zs6pu antimo caputo italian superfine 00 farina flour 2 2 lb bag
# Original summary: great flour for pizza crust
# Predicted summary:  great for pizza
#
#
# # 1000
# Text: yoga teacher offer yoga sessions restorative yoga workshops tea offered end classes occasion winter months students come love say smell takes right back bliss never anyone say spicy add milk stevia give try love wonderful tea
# Original summary: yummy tea a favorite for students
# Predicted summary:  great for training

# %%
# text = this is such a disgusting tea, I hate it so much argh,, so very very bad
text = input("Text: ")

clean = content_cleaner(text)

accepted = []
accepted.append(clean)

accepted = list(map(lambda x: 'starttoken '+ x + ' endtoken', accepted))

#convert text sequences into integer sequences
accepted = x_tokenizer.texts_to_sequences(accepted)

#ensures all sequences in the list have the same length
accepted = pad_sequences(accepted, maxlen = maximum_text_length, padding='post')

print("Predicted: ",predicted(accepted[0].reshape(1,maximum_text_length)))
# Out:
# Text: this is such a disgusting tea, I hate it so much argh,, so very very bad
# Predicted:   worst tea ever
